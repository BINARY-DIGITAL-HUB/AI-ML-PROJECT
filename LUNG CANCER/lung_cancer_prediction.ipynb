# %% [markdown]
# ### Library Importation

# %%
import pandas as pd 
import seaborn as sn
import numpy as np 
import warnings
import matplotlib.pyplot as plt
# removove warning
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Importation

# %%
# importing dataset
data  =  pd.read_csv('cancer patient data sets.csv')

# %%
# basic exploration 
data.head(3)
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# ...

# %%
data.sample(3)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 422    422       P479   45       1              6            7             7
# 122    122       P208   64       1              6            8             7
# 533    533       P579   45       1              6            7             7
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 422                     7             7                     6  ...        4
# 122                     7             7                     6  ...        9
# 533                     7             7                     6  ...        4
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 422            4                    5         6                      5
# 122            6                    5         7                      2
# 533            4                    5         6                      5
#
# ...

# %%
data.tail(3)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
# ...

# %% [markdown]
# ### Pre Data Exploratory Analysis (PDEA)

# %%
# columns in dataset 
data.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
# data type and column count 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
data.drop(columns=['index', 'Patient Id']).describe().T
# Out:
#                            count    mean        std   min    25%   50%   75%  \
# Age                       1000.0  37.174  12.005493  14.0  27.75  36.0  45.0
# Gender                    1000.0   1.402   0.490547   1.0   1.00   1.0   2.0
# Air Pollution             1000.0   3.840   2.030400   1.0   2.00   3.0   6.0
# Alcohol use               1000.0   4.563   2.620477   1.0   2.00   5.0   7.0
# Dust Allergy              1000.0   5.165   1.980833   1.0   4.00   6.0   7.0
# OccuPational Hazards      1000.0   4.840   2.107805   1.0   3.00   5.0   7.0
# Genetic Risk              1000.0   4.580   2.126999   1.0   2.00   5.0   7.0
# chronic Lung Disease      1000.0   4.380   1.848518   1.0   3.00   4.0   6.0
# Balanced Diet             1000.0   4.491   2.135528   1.0   2.00   4.0   7.0
# Obesity                   1000.0   4.465   2.124921   1.0   3.00   4.0   7.0
# Smoking                   1000.0   3.948   2.495902   1.0   2.00   3.0   7.0
# ...

# %%
plt.figure(figsize=(15, 15))
sn.heatmap(data.corr(), annot=True, fmt='.1f')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
sn.heatmap(data[data.columns[2:14]].corr(), annot=True, fmt='.1f')
# Out:
# <Axes: >

# %%
# data.corr()[data.corr() > 0.6]

# %%
data.columns[2:14]
# Out:
# Index(['Air Pollution', 'Alcohol use', 'Dust Allergy', 'OccuPational Hazards',
#        'Genetic Risk', 'chronic Lung Disease', 'Balanced Diet', 'Obesity',
#        'Smoking', 'Passive Smoker', 'Chest Pain', 'Coughing of Blood'],
#       dtype='object')

# %%
sn.scatterplot(data, y='chronic Lung Disease', x='OccuPational Hazards', hue='Gender', size='Level',size_order=['High', 'Medium', 'Low'], color=['r', 'g'])
# Out:
# <Axes: xlabel='OccuPational Hazards', ylabel='chronic Lung Disease'>

# %%
plt.figure(figsize=(15, 15))
data.hist(figsize=(15, 15))
plt.show()
plt.tight_layout(pad=7)

# %%
data.shape
# Out:
# (1000, 26)

# %%
sn.countplot(data ,x=data.Gender.value_counts())
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sn.distplot(data.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
data.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %% [markdown]
# ### Cleaning Data Set

# %%
# droping un-used comlumn
data = data[data.columns[2:]]
data.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0        4  ...        3            4                    2         2
# ...

# %%
print('UNIQUE VALUE')
print('======================================================\n')
unique_data = []
for col in data.columns: 
    unique = data[col].unique()
    unique_data.append(unique)
    # print(unique)

unique_data = np.array(unique_data)
unique_data
# Out:
# UNIQUE VALUE
# ...
# array([array([33, 17, 35, 37, 46, 52, 28, 44, 64, 39, 34, 27, 73, 36, 14, 24, 53,
#               62, 29, 65, 38, 19, 42, 32, 25, 45, 26, 48, 22, 18, 23, 47, 61, 55,
#               31, 49, 43, 51, 54, 63], dtype=int64)                              ,
#        array([1, 2], dtype=int64),
#        array([2, 3, 4, 7, 6, 5, 1, 8], dtype=int64),
#        array([4, 1, 5, 7, 8, 3, 6, 2], dtype=int64),
#        array([5, 6, 7, 4, 2, 8, 1, 3], dtype=int64),
#        array([4, 3, 5, 7, 2, 6, 8, 1], dtype=int64),
#        array([3, 4, 5, 6, 7, 2, 1], dtype=int64),
#        array([2, 4, 7, 6, 3, 5, 1], dtype=int64),
#        array([2, 6, 7, 4, 5, 3, 1], dtype=int64),
#        array([4, 2, 7, 3, 5, 6, 1], dtype=int64),
#        array([3, 2, 7, 8, 1, 6, 5, 4], dtype=int64),
#        array([2, 4, 3, 7, 6, 8, 5, 1], dtype=int64),
#        array([2, 4, 7, 3, 6, 5, 9, 8, 1], dtype=int64),
#        array([4, 3, 8, 9, 1, 5, 7, 6, 2], dtype=int64),
# ...

# %%
unique_df = pd.DataFrame(unique_data)
unique_df['attribute'] = data.columns
unique_df.rename({0:'Uniques Value'}, axis='columns')
# Out:
#                                         Uniques Value  \
# 0   [33, 17, 35, 37, 46, 52, 28, 44, 64, 39, 34, 2...
# 1                                              [1, 2]
# 2                            [2, 3, 4, 7, 6, 5, 1, 8]
# 3                            [4, 1, 5, 7, 8, 3, 6, 2]
# 4                            [5, 6, 7, 4, 2, 8, 1, 3]
# 5                            [4, 3, 5, 7, 2, 6, 8, 1]
# 6                               [3, 4, 5, 6, 7, 2, 1]
# 7                               [2, 4, 7, 6, 3, 5, 1]
# 8                               [2, 6, 7, 4, 5, 3, 1]
# 9                               [4, 2, 7, 3, 5, 6, 1]
# 10                           [3, 2, 7, 8, 1, 6, 5, 4]
# 11                           [2, 4, 3, 7, 6, 8, 5, 1]
# 12                        [2, 4, 7, 3, 6, 5, 9, 8, 1]
# 13                        [4, 3, 8, 9, 1, 5, 7, 6, 2]
# 14                           [3, 1, 8, 4, 5, 9, 2, 6]
# 15                           [4, 3, 7, 2, 6, 5, 1, 8]
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Gender                    1000 non-null   int64
#  2   Air Pollution             1000 non-null   int64
#  3   Alcohol use               1000 non-null   int64
#  4   Dust Allergy              1000 non-null   int64
#  5   OccuPational Hazards      1000 non-null   int64
#  6   Genetic Risk              1000 non-null   int64
#  7   chronic Lung Disease      1000 non-null   int64
#  8   Balanced Diet             1000 non-null   int64
#  9   Obesity                   1000 non-null   int64
#  10  Smoking                   1000 non-null   int64
#  11  Passive Smoker            1000 non-null   int64
#  12  Chest Pain                1000 non-null   int64
#  13  Coughing of Blood         1000 non-null   int64
# ...

# %%
# label encoding
sn.barplot(data=data, x='Level', y='Gender', hue='Gender')
# Out:
# <Axes: xlabel='Level', ylabel='Gender'>

# %%
sn.scatterplot(data, y='Genetic Risk', x='Balanced Diet')
# Out:
# <Axes: xlabel='Balanced Diet', ylabel='Genetic Risk'>

# %%
sn.countplot(x='Level', hue='Gender', data=data)
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# ### Lable Transformation

# %%
data.Level = data.Level.astype('category')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Gender                    1000 non-null   int64
#  2   Air Pollution             1000 non-null   int64
#  3   Alcohol use               1000 non-null   int64
#  4   Dust Allergy              1000 non-null   int64
#  5   OccuPational Hazards      1000 non-null   int64
#  6   Genetic Risk              1000 non-null   int64
#  7   chronic Lung Disease      1000 non-null   int64
#  8   Balanced Diet             1000 non-null   int64
#  9   Obesity                   1000 non-null   int64
#  10  Smoking                   1000 non-null   int64
#  11  Passive Smoker            1000 non-null   int64
#  12  Chest Pain                1000 non-null   int64
#  13  Coughing of Blood         1000 non-null   int64
# ...

# %%
data['Level'] = data.Level.cat.codes
data.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0        4  ...        3            4                    2         2
# ...

# %%
level_mapper = dict(zip(data['Level'].cat.categories, range(len(data['Level'].cat.categories))))
level_mapper
# Out:
# {'High': 0, 'Low': 1, 'Medium': 2}

# %% [markdown]
# ### Data Splitting

# %%
data
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
# independent variable 
X = data[data.columns[:-1]]
# dependent variable
y = data['Level']

# %%
X.shape
# Out:
# (1000, 23)

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print('X train : ', X_train.shape)
print('X test : ', X_test.shape)
# Out:
# X train :  (800, 23)
# X test :  (200, 23)

# %% [markdown]
# ### Model Traning

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics

# creating helper function 
def model_prediction_and_report(model, xtrain, ytrain, xtest, ytest):
    data_holder = {'train_score':None, 'test_score':None, 'acc':None, 'pre':None, 'rec':None, 'report':None, 'matrix':None, 'prediction':None}
    model.fit(xtrain, ytrain)
    train_score= model.score(xtrain, ytrain)
    test_score = model.score(xtest, ytest)
    prediction = model.predict(xtest)
    acc = metrics.accuracy_score(ytest , prediction)
    pre = metrics.precision_score(ytest , prediction, average='weighted')
    rec = metrics.recall_score(ytest , prediction, average='weighted')
    report = classification_report(ytest, prediction)
    matrix = confusion_matrix(ytest, prediction)

    # data project 
    data_holder['train_score'] = train_score
    data_holder['test_score'] = test_score
    data_holder['acc'] = acc
    data_holder['pre'] = pre
    data_holder['rec'] = rec
    data_holder['report'] = report
    data_holder['matrix'] = matrix
    data_holder['prediction'] = prediction

    return data_holder

# %% [markdown]
# ### SVM

# %%
# Support Vector Machine... 
svm = SVC()
svm_report = model_prediction_and_report(svm, X_train, y_train, X_test, y_test)

# %%
svm_report.keys()
# Out:
# dict_keys(['train_score', 'test_score', 'acc', 'pre', 'rec', 'report', 'matrix', 'prediction'])

# %%
list(svm_report.keys())[:-2]
for key  in list(svm_report.keys())[:-4]: 
    print(f'{" ".join(key.split("_"))}  ===>  {svm_report[key]}')
# Out:
# train score  ===>  0.9725
# test score  ===>  0.96
# acc  ===>  0.96
# pre  ===>  0.961038961038961

# %%
print(svm_report['report'])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        73
#            1       1.00      0.93      0.96        57
#            2       0.94      0.94      0.94        70
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200

# %%
sn.heatmap(svm_report['matrix'], annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %%
svm_report['matrix'].ravel()
# Out:
# array([73,  0,  0,  0, 53,  4,  4,  0, 66], dtype=int64)

# %%
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = svm_report['matrix'].ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
# TN = 73 ---,  FP = 0 ---,  FN = 0 ----, TP = 53
# TN = 53 ---,  FP = 0 ---,  FN = 4 ----, TP = 66
# TN = 66 ---,  FP = 0 ---,  FN = 4 ----, TP = 73

# %% [markdown]
# ### Naive Bayes Algorithm

# %%
# Naive Bayes Algorithm
nb = GaussianNB()
nb_report = model_prediction_and_report(nb, X_train, y_train, X_test, y_test)

# %%
list(nb_report.keys())[:-2]
for key  in list(nb_report.keys())[:-4]: 
    print(f'{" ".join(key.split("_"))}  ===>  {nb_report[key]}')
# Out:
# train score  ===>  0.89
# test score  ===>  0.89
# acc  ===>  0.89
# pre  ===>  0.8987596899224806

# %%
print(nb_report['report'])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88        73
#            1       1.00      0.89      0.94        57
#            2       0.90      0.81      0.86        70
#
#     accuracy                           0.89       200
#    macro avg       0.91      0.89      0.89       200
# weighted avg       0.90      0.89      0.89       200

# %%
sn.heatmap(nb_report['matrix'], annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %%
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = nb_report['matrix'].ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
# TN = 70 ---,  FP = 0 ---,  FN = 3 ----, TP = 51
# TN = 51 ---,  FP = 3 ---,  FN = 3 ----, TP = 57
# TN = 57 ---,  FP = 0 ---,  FN = 13 ----, TP = 70

# %% [markdown]
# ## Sex Protected Feature

# %%
# X_test
PROTECTED_VARIABLE = 'Gender'
MALE = 2
FEMALE = 1

# extracting indices
male_indices = np.where(X_test[PROTECTED_VARIABLE] == MALE)[0]
female_indices = np.where(X_test[PROTECTED_VARIABLE] == FEMALE)[0]

# show 
print('Indices of males: {} ======> Size: {}'.format(male_indices, len(male_indices)))
print('Indices of females: {} ========> Size: {}'.format(female_indices, len(female_indices)))
# Out:
# Indices of males: [  1   4   5   8   9  13  14  18  19  23  27  28  33  39  40  41  44  46
#   48  50  55  58  59  61  62  64  65  71  75  76  80  82  83  85  86  87
#   88  91  92  97 101 111 112 113 117 118 120 121 122 125 127 129 133 135
#  137 140 143 145 150 151 152 153 155 157 158 161 162 165 167 168 169 171
#  172 173 181 182 188 189 190 197] ======> Size: 80
# Indices of females: [  0   2   3   6   7  10  11  12  15  16  17  20  21  22  24  25  26  29
#   30  31  32  34  35  36  37  38  42  43  45  47  49  51  52  53  54  56
#   57  60  63  66  67  68  69  70  72  73  74  77  78  79  81  84  89  90
#   93  94  95  96  98  99 100 102 103 104 105 106 107 108 109 110 114 115
#  116 119 123 124 126 128 130 131 132 134 136 138 139 141 142 144 146 147
#  148 149 154 156 159 160 163 164 166 170 174 175 176 177 178 179 180 183
#  184 185 186 187 191 192 193 194 195 196 198 199] ========> Size: 120

# %%
# using the male index to collect value map to male in y_test 
y_test_male = [y_test.values[index] for index in male_indices]

# using the female index to collect value map to female in y_test 
y_test_female = [y_test.values[index] for index in female_indices]

# %%
# accessing the the male and female index prediction make by the
# machine leanring algorithm..

# %%
# extraction for SVM
y_male_prediction = [svm_report['prediction'][index] for index in male_indices]
y_female_prediction = [svm_report['prediction'][index] for index in female_indices]

# %%
# extraction for Naive Bayes 
y_male_prediction_nb = [nb_report['prediction'][index] for index in male_indices]
y_female_prediction_nb = [nb_report['prediction'][index] for index in female_indices]

# %%
# extraction for Naive Bayes 
y_male_prediction_nb = [nb_report['prediction'][index] for index in male_indices]
y_female_prediction_nb = [nb_report['prediction'][index] for index in female_indices]

# %% [markdown]
# ### SVM MALE PROTECTED

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - MALE')
print('-------------------------------------------------------------')
cr_male = metrics.classification_report(y_test_male, y_male_prediction)
print(cr_male)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_male_report = metrics.confusion_matrix(y_test_male, y_male_prediction)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_male_report.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - MALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       1.00      0.97      0.98        30
#            2       0.97      0.97      0.97        30
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.98        80
# weighted avg       0.98      0.97      0.98        80
#
# TN = 20 ---,  FP = 0 ---,  FN = 0 ----, TP = 29
# TN = 29 ---,  FP = 0 ---,  FN = 1 ----, TP = 29
# TN = 29 ---,  FP = 0 ---,  FN = 1 ----, TP = 20

# %%
# accuracy, precision and recall diction 
acc_pre_re_diction = {'model':[], 'acc':[], 'pre':[], 'rec':[] }
acc_male = metrics.accuracy_score(y_test_male , y_male_prediction)
pre_male = metrics.precision_score(y_test_male , y_male_prediction, average='weighted')
rec_male = metrics.recall_score(y_test_male , y_male_prediction, average='weighted')
acc_pre_re_diction['model'].append('SVM-MALE')
acc_pre_re_diction['acc'].append(acc_male)
acc_pre_re_diction['pre'].append(pre_male)
acc_pre_re_diction['rec'].append(rec_male)

# %%
sn.heatmap(cm_male_report, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %% [markdown]
# ### SVM - FEMALE PROTECTED

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - FEMALE')
print('-------------------------------------------------------------')
cr_female = metrics.classification_report(y_test_female, y_female_prediction)
print(cr_female)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_female_report = metrics.confusion_matrix(y_test_female, y_female_prediction)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_female_report.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - FEMALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        53
#            1       1.00      0.89      0.94        27
#            2       0.93      0.93      0.93        40
#
#     accuracy                           0.95       120
#    macro avg       0.96      0.94      0.95       120
# weighted avg       0.95      0.95      0.95       120
#
# TN = 53 ---,  FP = 0 ---,  FN = 0 ----, TP = 24
# TN = 24 ---,  FP = 0 ---,  FN = 3 ----, TP = 37
# TN = 37 ---,  FP = 0 ---,  FN = 3 ----, TP = 53

# %%
acc_female = metrics.accuracy_score(y_test_female , y_female_prediction)
pre_female = metrics.precision_score(y_test_female , y_female_prediction, average='weighted')
rec_female = metrics.recall_score(y_test_female , y_female_prediction, average='weighted')
acc_pre_re_diction['model'].append('SVM-FEMALE')
acc_pre_re_diction['acc'].append(acc_female)
acc_pre_re_diction['pre'].append(pre_female)
acc_pre_re_diction['rec'].append(rec_female)

# %%
sn.heatmap(cm_female_report, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %%
acc_pre_re_diction
# Out:
# {'model': ['SVM-MALE', 'SVM-FEMALE'],
#  'acc': [0.975, 0.95],
#  'pre': [0.9755952380952382, 0.9513392857142856],
#  'rec': [0.975, 0.95]}

# %%
svm_protected_result = pd.DataFrame(acc_pre_re_diction)
svm_protected_result
# Out:
#         model    acc       pre    rec
# 0    SVM-MALE  0.975  0.975595  0.975
# 1  SVM-FEMALE  0.950  0.951339  0.950

# %% [markdown]
# ## Naive Bayes Male Protected

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR Naive-Bayes - MALE')
print('-------------------------------------------------------------')
cr_male_nb = metrics.classification_report(y_test_male, y_male_prediction_nb)
print(cr_male_nb)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_male_report_nb = metrics.confusion_matrix(y_test_male, y_male_prediction_nb)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_male_report_nb.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR Naive-Bayes - MALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        20
#            1       1.00      0.97      0.98        30
#            2       0.93      0.90      0.92        30
#
#     accuracy                           0.94        80
#    macro avg       0.93      0.94      0.93        80
# weighted avg       0.94      0.94      0.94        80
#
# TN = 19 ---,  FP = 0 ---,  FN = 0 ----, TP = 29
# TN = 29 ---,  FP = 1 ---,  FN = 1 ----, TP = 27
# TN = 27 ---,  FP = 0 ---,  FN = 3 ----, TP = 19

# %%
# accuracy, precision and recall diction 
acc_pre_re_diction = {'model':[], 'acc':[], 'pre':[], 'rec':[] }
acc_male = metrics.accuracy_score(y_test_male , y_male_prediction_nb)
pre_male = metrics.precision_score(y_test_male , y_male_prediction_nb, average='weighted')
rec_male = metrics.recall_score(y_test_male , y_male_prediction_nb, average='weighted')
acc_pre_re_diction['model'].append('Naive Bayes -MALE')
acc_pre_re_diction['acc'].append(acc_male)
acc_pre_re_diction['pre'].append(pre_male)
acc_pre_re_diction['rec'].append(rec_male)

# %%
sn.heatmap(cm_male_report_nb, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %% [markdown]
# ## Naive Bayes Female Protected

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR Naive-Bayes - FEMALE')
print('-------------------------------------------------------------')
cr_female_nb = metrics.classification_report(y_test_female, y_female_prediction_nb)
print(cr_female_nb)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_female_report_nb = metrics.confusion_matrix(y_test_female, y_female_prediction_nb)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_female_report_nb.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR Naive-Bayes - FEMALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87        53
#            1       1.00      0.81      0.90        27
#            2       0.88      0.75      0.81        40
#
#     accuracy                           0.86       120
#    macro avg       0.89      0.84      0.86       120
# weighted avg       0.87      0.86      0.86       120
#
# TN = 51 ---,  FP = 0 ---,  FN = 3 ----, TP = 22
# TN = 22 ---,  FP = 2 ---,  FN = 2 ----, TP = 30
# TN = 30 ---,  FP = 0 ---,  FN = 10 ----, TP = 51

# %%
acc_female = metrics.accuracy_score(y_test_female , y_female_prediction_nb)
pre_female = metrics.precision_score(y_test_female , y_female_prediction_nb, average='weighted')
rec_female = metrics.recall_score(y_test_female , y_female_prediction_nb, average='weighted')
acc_pre_re_diction['model'].append('Naive Bayes -FEMALE')
acc_pre_re_diction['acc'].append(acc_female)
acc_pre_re_diction['pre'].append(pre_female)
acc_pre_re_diction['rec'].append(rec_female)

# %%
sn.heatmap(cm_female_report_nb, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# <Axes: >

# %%
acc_pre_re_diction
# Out:
# {'model': ['Naive Bayes -MALE', 'Naive Bayes -FEMALE'],
#  'acc': [0.9375, 0.8583333333333333],
#  'pre': [0.9400470219435736, 0.8710707720588236],
#  'rec': [0.9375, 0.8583333333333333]}

# %%
nb_protected_result = pd.DataFrame(acc_pre_re_diction)
nb_protected_result
# Out:
#                  model       acc       pre       rec
# 0    Naive Bayes -MALE  0.937500  0.940047  0.937500
# 1  Naive Bayes -FEMALE  0.858333  0.871071  0.858333

# %% [markdown]
# ### Phase Two (Dimensionality Reduction)

# %%
# selecting high correlated feature

# %%
reduce_data = data[data.columns[2:14]]
reduce_data.head()
# Out:
#    Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0              2            4             5                     4
# 1              3            1             5                     3
# 2              4            5             6                     5
# 3              7            7             7                     7
# 4              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0             3                     2              2        4        3
# 1             4                     2              2        2        2
# 2             5                     4              6        7        2
# 3             6                     7              7        7        7
# 4             7                     6              7        7        8
#
#    Passive Smoker  Chest Pain  Coughing of Blood
# 0               2           2                  4
# ...

# %%
reduce_data['target'] = data.Level
reduce_data.head()
# Out:
#    Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0              2            4             5                     4
# 1              3            1             5                     3
# 2              4            5             6                     5
# 3              7            7             7                     7
# 4              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0             3                     2              2        4        3
# 1             4                     2              2        2        2
# 2             5                     4              6        7        2
# 3             6                     7              7        7        7
# 4             7                     6              7        7        8
#
#    Passive Smoker  Chest Pain  Coughing of Blood  target
# 0               2           2                  4       1
# ...

# %%
reduce_data.corr()
# Out:
#                       Air Pollution  Alcohol use  Dust Allergy  \
# Air Pollution              1.000000     0.747293      0.637503
# Alcohol use                0.747293     1.000000      0.818644
# Dust Allergy               0.637503     0.818644      1.000000
# OccuPational Hazards       0.608924     0.878786      0.835860
# Genetic Risk               0.705276     0.877210      0.787904
# chronic Lung Disease       0.626701     0.763576      0.619556
# Balanced Diet              0.524873     0.653352      0.647197
# Obesity                    0.601468     0.669312      0.700676
# Smoking                    0.481902     0.547035      0.358691
# Passive Smoker             0.606764     0.592576      0.560002
# Chest Pain                 0.585734     0.717242      0.639983
# Coughing of Blood          0.607829     0.667612      0.625291
# target                    -0.577269    -0.434071     -0.264926
#
#                       OccuPational Hazards  Genetic Risk  \
# ...

# %%
print('original : ' ,  data.shape )
print('reduce : ' ,  reduce_data.shape )
# Out:
# original :  (1000, 24)
# reduce :  (1000, 13)

# %%
# split data
# independent variable 
X = reduce_data[reduce_data.columns[:-1]]
# dependent variable
y = reduce_data['target']



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


print('X train : ', X_train.shape)
print('X test : ', X_test.shape)
# Out:
# X train :  (800, 12)
# X test :  (200, 12)

# %% [markdown]
# ## SVM

# %%
# Support Vector Machine... 
svm = SVC()
svm_report1 = model_prediction_and_report(svm, X_train, y_train, X_test, y_test)

# %%
list(svm_report1.keys())[:-2]
for key  in list(svm_report1.keys())[:-4]: 
    print(f'{" ".join(key.split("_"))}  ===>  {svm_report1[key]}')

print(svm_report1['report'])

sn.heatmap(svm_report1['matrix'], annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# train score  ===>  0.97625
# test score  ===>  0.99
# acc  ===>  0.99
# pre  ===>  0.9902469135802469
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        58
#            1       1.00      0.97      0.98        63
#            2       0.98      1.00      0.99        79
#
#     accuracy                           0.99       200
#    macro avg       0.99      0.99      0.99       200
# weighted avg       0.99      0.99      0.99       200
# <Axes: >

# %% [markdown]
# ## Naive Bayes

# %%
# Naive Bayes Algorithm
nb = GaussianNB()
nb_report1 = model_prediction_and_report(nb, X_train, y_train, X_test, y_test)

list(nb_report1.keys())[:-2]
for key  in list(nb_report1.keys())[:-4]: 
    print(f'{" ".join(key.split("_"))}  ===>  {nb_report1[key]}')

print(nb_report1['report'])

sn.heatmap(nb_report1['matrix'], annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
# train score  ===>  0.71875
# test score  ===>  0.66
# acc  ===>  0.66
# pre  ===>  0.664810194519497
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        58
#            1       0.57      0.78      0.66        63
#            2       0.68      0.32      0.43        79
#
#     accuracy                           0.66       200
#    macro avg       0.67      0.70      0.65       200
# weighted avg       0.66      0.66      0.63       200
# <Axes: >

# %%
''
# Out:
# ''

# %% [markdown]
# EXTRACTING PROTECTED VARIABLES

# %%
''
# Out:
# ''

# %%
y_male_prediction = [svm_report1['prediction'][index] for index in male_indices]
y_female_prediction = [svm_report1['prediction'][index] for index in female_indices]
# extraction for Naive Bayes 
y_male_prediction_nb = [nb_report1['prediction'][index] for index in male_indices]
y_female_prediction_nb = [nb_report1['prediction'][index] for index in female_indices]

# %% [markdown]
# ### SVM- MALE PROTECTED

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - MALE')
print('-------------------------------------------------------------')
cr_male = metrics.classification_report(y_test_male, y_male_prediction)
print(cr_male)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_male_report = metrics.confusion_matrix(y_test_male, y_male_prediction)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_male_report.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))


# accuracy, precision and recall diction 
acc_pre_re_diction = {'model':[], 'acc':[], 'pre':[], 'rec':[] }
acc_male = metrics.accuracy_score(y_test_male , y_male_prediction)
pre_male = metrics.precision_score(y_test_male , y_male_prediction, average='weighted')
rec_male = metrics.recall_score(y_test_male , y_male_prediction, average='weighted')
acc_pre_re_diction['model'].append('SVM-MALE')
acc_pre_re_diction['acc'].append(acc_male)
acc_pre_re_diction['pre'].append(pre_male)
acc_pre_re_diction['rec'].append(rec_male)

sn.heatmap(cm_male_report, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - MALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.28      0.35      0.31        20
#            1       0.57      0.40      0.47        30
#            2       0.38      0.43      0.41        30
#
#     accuracy                           0.40        80
#    macro avg       0.41      0.39      0.40        80
# weighted avg       0.43      0.40      0.41        80
#
# TN = 7 ---,  FP = 3 ---,  FN = 7 ----, TP = 12
# TN = 12 ---,  FP = 10 ---,  FN = 11 ----, TP = 13
# TN = 13 ---,  FP = 3 ---,  FN = 11 ----, TP = 7
# <Axes: >

# %% [markdown]
# ### SVM-FEMALE PROTECTED

# %%
print('      CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - FEMALE')
print('-------------------------------------------------------------')
cr_female = metrics.classification_report(y_test_female, y_female_prediction)
print(cr_female)

# COMPUTING ACCURACY PRECISION AND RECALL FROM CONFUSION MATRIX
cm_female_report = metrics.confusion_matrix(y_test_female, y_female_prediction)
TN1, FP1, FP2, FN1, TN2, FN2, FN3, FN4, TN3 = cm_female_report.ravel()

# Print the metrics and values
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN1, FP1, FN1, TN2))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN2, FP2, FN2, TN3))
print('TN = {} ---,  FP = {} ---,  FN = {} ----, TP = {}'.format(TN3, FP1, FN3, TN1))

# COLLECTING ACCURACY PRECISION AND RECALL
acc_female = metrics.accuracy_score(y_test_female , y_female_prediction)
pre_female = metrics.precision_score(y_test_female , y_female_prediction, average='weighted')
rec_female = metrics.recall_score(y_test_female , y_female_prediction, average='weighted')
acc_pre_re_diction['model'].append('SVM-FEMALE')
acc_pre_re_diction['acc'].append(acc_female)
acc_pre_re_diction['pre'].append(pre_female)
acc_pre_re_diction['rec'].append(rec_female)

# SHOWING THE CONFUSION MATRIX
sn.heatmap(cm_female_report, annot=True, xticklabels=level_mapper.keys(), yticklabels=level_mapper.keys())
# Out:
#       CLASSIFICATION REPORT & CONFUSION MATRIX FOR SVM - FEMALE
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.48      0.30      0.37        53
#            1       0.25      0.37      0.30        27
#            2       0.36      0.42      0.39        40
#
#     accuracy                           0.36       120
#    macro avg       0.37      0.37      0.35       120
# weighted avg       0.39      0.36      0.36       120
#
# TN = 16 ---,  FP = 17 ---,  FN = 7 ----, TP = 10
# TN = 10 ---,  FP = 20 ---,  FN = 10 ----, TP = 17
# TN = 17 ---,  FP = 17 ---,  FN = 10 ----, TP = 16
# <Axes: >

# %%
svm_protected_result1 = pd.DataFrame(acc_pre_re_diction)
svm_protected_result1
# Out:
#         model       acc       pre       rec
# 0    SVM-MALE  0.400000  0.427668  0.400000
# 1  SVM-FEMALE  0.358333  0.390959  0.358333

# %% [markdown]
# # FINAL RESULT PRESENTATION

# %%
import matplotlib.pyplot as plt

# %%
# # PRESENTING THE SVM AND NAIVE BAYES
sa, sp, sr = svm_report['acc'], svm_report['pre'], svm_report['rec']
na, npp, nr = nb_report['acc'], nb_report['pre'], nb_report['rec']

# # 
# model_results = {'metric':['accuracy', 'precision', 'recall'] , 'svm': [sa, sp, sr], 'naive bayes': [na, npp, nr]}
# print(pd.DataFrame(model_results))
# sn.set()

# fig, ax = plt.subplots(1,2, figsize=(10,5))
# fig.suptitle('MODEL PERFORMANCE WITH NO DIMENSION REDUCTION')

# sn.barplot(y=[sa, sp, sr],x= list(svm_report.keys())[2:5], ax=ax[0])
# ax[0].set_title('SVM METRICS')
# ax[0].set_xlabel('METRICS')
# ax[0].set_ylabel('ACCURACY')


# sn.barplot(y=[na, npp, nr],x= list(svm_report.keys())[2:5], ax=ax[1])
# ax[1].set_title('NAIVE BAYES METRICS')
# ax[1].set_xlabel('METRICS')
# ax[1].set_ylabel('ACCURACY')

# plt.show()

# %%
import numpy as np
sa, sp, sr = svm_report['acc'], svm_report['pre'], svm_report['rec']
na, npp, nr = nb_report['acc'], nb_report['pre'], nb_report['rec']

model_results = {'metric':['accuracy', 'precision', 'recall'] , 'svm': [sa, sp, sr], 'naive bayes': [na, npp, nr]}
print(pd.DataFrame(model_results))
sn.set()



svm = [sa, sp, sr]
nb =  [na, npp, nr]
lbl = ['accuracy', 'precision', 'recall']

xtick = np.arange(len(lbl))


plt.bar(xtick-0.2, svm, 0.4, label='SVM')
plt.bar(xtick+0.2, nb, 0.4, label='NB')
plt.legend()
plt.title('MODEL PERFORMANCE WITH 24 DIMENSION')
plt.show
# Out:
#       metric       svm  naive bayes
# 0   accuracy  0.960000      0.89000
# 1  precision  0.961039      0.89876
# 2     recall  0.960000      0.89000
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
sa, sp, sr = svm_report1['acc'], svm_report1['pre'], svm_report1['rec']
na, npp, nr = nb_report1['acc'], nb_report1['pre'], nb_report1['rec']

model_results1 = {'metric':['accuracy', 'precision', 'recall'] , 'svm': [sa, sp, sr], 'naive bayes': [na, npp, nr]}
print(pd.DataFrame(model_results1))
sn.set()


svm = [sa, sp, sr]
nb =  [na, npp, nr]
lbl = ['accuracy', 'precision', 'recall']

xtick = np.arange(len(lbl))


plt.bar(xtick-0.2, svm, 0.4, label='SVM')
plt.bar(xtick+0.2, nb, 0.4, label='NB')
plt.legend()
plt.title('MODEL PERFORMANCE WITH 12 DIMENSION ATTRIBUTE')
plt.show
# Out:
#       metric       svm  naive bayes
# 0   accuracy  0.990000      0.66000
# 1  precision  0.990247      0.66481
# 2     recall  0.990000      0.66000
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
svm_protected_result
# Out:
#         model    acc       pre    rec
# 0    SVM-MALE  0.975  0.975595  0.975
# 1  SVM-FEMALE  0.950  0.951339  0.950

# %%
lbl = svm_protected_result.model.to_list()
acc, pre, rec = svm_protected_result.acc.to_list(), svm_protected_result.pre.to_list(), svm_protected_result.rec.to_list()

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
plt.tight_layout()

svm_protected_result.set_index('model').plot(kind='bar', ax=ax[0])
ax[0].set_title('SVM PROTECTECTED WITH 22 FEATURES')
ax[0].set_xlabel('METRICS')
ax[0].set_ylabel('ACCURACY')

svm_protected_result1.set_index('model').plot(kind='bar',  ax=ax[1])
ax[1].set_title('SVM PROTECTECTED WITH 12 FEATURES')
ax[1].set_xlabel('METRICS')
ax[1].set_ylabel('ACCURACY')
# Out:
# Text(507.60227272727263, 0.5, 'ACCURACY')

# %%
# pd.concat([pd.DataFrame(model_results),(pd.DataFrame(model_results1))]).T
