# %%
#     =====================================================================================   #
#                                       FIRST SECTION CODE                                    #
#     =====================================================================================   #

# IMPORTING IMPORTANT MODULE..... 
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pandas as pd

# IMPORTING ORIGINAL DATA 
jamb_data = pd.read_csv('Newrecord/fedpoedefile.csv')

# GETTING ATTRIBUTE FROM ORIGINAL DATA
candidate_name = jamb_data["RG_CANDNAME"].values
candidate_reg = jamb_data["RG_NUM"].values
names = list(candidate_name)
regs = list(candidate_reg)
# print(names)
# print(regs)

# GENERATING NEW DATAFRAME
gen_df = pd.DataFrame()
    
try:
    gen_df = pd.read_csv('Newrecord/fedpoede_gen/fedpoede_gen.csv', index=False)
except Exception: 
    pass

def create_dataframe(dataframe,  add=''):
    attributes = []

    for attr in dataframe.columns: 
        attributes.append(attr)
    if add != '':
        attributes.append(add)

    df = pd.DataFrame([] , columns=attributes)

    return df , attributes


if gen_df.empty:
    print('original data is empty')
    gen_df , _ = create_dataframe(jamb_data, 'Contact')

else: 
    pass
# Out:
# original data is empty

# %%
#     =====================================================================================   #
#                                HELPER METHOD FOR SECTION TWO                                #
#     =====================================================================================   #




# helper method to valide content compatibility 

def check_content_matching(o_reg='data_reg' , o_name='d_name' , m_reg='mine_reg' , m_name = 'm_name'): 
    
    #   : o_reg / the import jamb student registration number 
    #   : o_name / the import jamb student name 
    #   : m_reg / the mined student registration number 
    #   : m_name / the mined student name 

    validate = False 
    if (m_reg.upper().strip() == o_reg.upper().strip() and m_name.lower() in o_name.lower().split()):
        validate = True
    else : 
        validate = False
    return validate ; 

# helper method to had new row to the new table
def add_row(old_table , new_table, tel='',  m_reg = ''):
    
    if m_reg != '':
        d = old_table[old_table[old_table.columns[0]] == m_reg]
        old_val = d.values
#         print(old_val.flatten())
        temp_value = []
        for value in list(old_val.flatten()):
            temp_value.append(value)

#         print('TEL:' , tel)

        if tel != '':
            temp_value.append(str(tel))
            
            print(temp_value)
            new_table.loc[len(new_table)] = temp_value
            
            new_table.to_csv('Newrecord/fedpoede_gen/fedpoede_gen.csv')
            print('add row successfully..........')
            return new_table
                
# add_row(jamb_data, gen_df , tel, reg_number)

# %%
#     =====================================================================================   #
#                                       SECOND SECTION CODE                                   #
#     =====================================================================================   #

# eporting to json 

#  to json ...
import json as j
# NAVIGATING THE WEB BROWSER USING THE STUDENT REGISTRATION NUMBER

driver= webdriver.Chrome()

def fetch_info(reg_number):
    driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip') 
    reg = driver.find_element('id' , "txtRegNumber")
    reg.send_keys(reg_number)

    # submitting form
    # reg.submit()
    sb = driver.find_element('id' , "lnkSearch")

    sb.click()
    # driver.refresh()
    # print('WEB PAGE ', driver.current_url)


    # getting data from html document
    print('fetching content')
    url = f'https://efacility.jamb.gov.ng/TempFiles/Main_Examination_Slip_{reg_number}.htm'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    data = soup.find_all('label')

    return data , len(data)


#  scraping through web for contact 

for index in range(635     , len(regs)): 
    reg = regs[index]
    name = names[index]
      
    
#         with  open('reg_cache.json','w') as file:  
#             file.dump({'last_reg':reg ,  'last_name':name , 'index':index})

    
    print()
    print(f'==== SOURCE FILE SIZE IS ==>  {jamb_data.shape[0]}')
    print('===================================================')
    print(f'   START MINING   FOR :  {reg} : index : {index}  ')
    print('===================================================')

    data , lenght = fetch_info(reg)
    if lenght != 0 :
            
        # printing data for confirmation
        try:
            surname = data[1].get_text()
            firstname = data[2].get_text()
            othername = data[4].get_text()
            tel = data[12].get_text()
            reg_number = data[15].get_text()

            print('Surname : ' , surname)
            print('Fist Name : ', firstname)
            print('Other Name : ',  othername)
            print('Telephone : ' , tel)
            print('Registion Number : ' , reg_number)


            valid = check_content_matching(reg, name , reg_number, surname)
            print('IS VALID ? ', valid)
            if valid :
                print('                     STUDENT CONFIRMED... ')
                add_row(jamb_data, gen_df , tel, reg_number)
                
        except Exception:
            print('error')
                  
    print('==================================================')
    print(f'              END MINING     No.   {index}       ')
    print('==================================================')
        
        
    
            
            

        
print('==================================================')
print(f'            FINAL END OF MINING                  ')
print('==================================================')
# Out:
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210565866HF : index : 0
# ===================================================
# fetching content
# Surname :  Moses
# Fist Name :  Ifeoluwa
# Other Name :  Gideon
# Telephone :  07044844347
# Registion Number :  202210565866HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210565866HF', 'Moses Ifeoluwa Gideon', 'M', 'OSUN', 250, 'Computer Science', 20.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '07044844347']
# add row successfully..........
# ==================================================
#               END MINING     No.   0
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210368202BF : index : 1
# ===================================================
# fetching content
# Surname :  Oladoye
# Fist Name :  Ibraheem
# Other Name :  Abiodun
# Telephone :  09160727625
# Registion Number :  202210368202BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210368202BF', 'Oladoye Ibraheem Abiodun', 'M', 'OSUN', 246, 'Accountancy', 36.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '09160727625']
# add row successfully..........
# ==================================================
#               END MINING     No.   1
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211329313DF : index : 2
# ===================================================
# fetching content
# Surname :  Oladepo
# Fist Name :  Suliyat
# Other Name :  Bolajoko
# Telephone :  09083504118
# Registion Number :  202211329313DF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211329313DF', 'Oladepo Suliyat Bolajoko', 'F', 'OSUN', 245, 'Horticultural Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OSOGBO', '09083504118']
# add row successfully..........
# ==================================================
#               END MINING     No.   2
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211185110JF : index : 3
# ===================================================
# fetching content
# Surname :  Oladoye
# Fist Name :  Precious
# Other Name :  Oluwapamilerin
# Telephone :  07045691938
# Registion Number :  202211185110JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211185110JF', 'Oladoye Precious Oluwapamilerin', 'F', 'OSUN', 243, 'Library & Information Science', 43.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EJIGBO', '07045691938']
# add row successfully..........
# ==================================================
#               END MINING     No.   3
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210932813HF : index : 4
# ===================================================
# fetching content
# Surname :  Olanrewaju
# Fist Name :  Abdullahi
# Other Name :  Olayemi
# Telephone :  09137456243
# Registion Number :  202210932813HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210932813HF', 'Olanrewaju Abdullahi Olayemi', 'M', 'OSUN', 241, 'Civil Engineering Technology', 26.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '09137456243']
# add row successfully..........
# ==================================================
#               END MINING     No.   4
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210364070GA : index : 5
# ===================================================
# fetching content
# Surname :  Adedokun
# Fist Name :  Waliyat
# Other Name :  Omotoyosi
# Telephone :  07017055456
# Registion Number :  202210364070GA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210364070GA', 'Adedokun Waliyat Omotoyosi', 'F', 'OSUN', 240, 'Science Laboratory Technology', 46.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'BORIPE', '07017055456']
# add row successfully..........
# ==================================================
#               END MINING     No.   5
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211717780HA : index : 6
# ===================================================
# fetching content
# Surname :  Afolabi
# Fist Name :  Ayomide
# Other Name :  Joseph
# Telephone :  07025914505
# Registion Number :  202211717780HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211717780HA', 'Afolabi Ayomide Joseph', 'M', 'OSUN', 240, 'Business Administration & Management', 63.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'BORIPE', '07025914505']
# add row successfully..........
# ==================================================
#               END MINING     No.   6
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210537796BF : index : 7
# ===================================================
# fetching content
# Surname :  Amos
# Fist Name :  Emmanuel
# Other Name :  Monday
# Telephone :  08066927143
# Registion Number :  202210537796BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210537796BF', 'Amos Emmanuel Monday', 'M', 'AKWA IBOM', 239, 'Accountancy', 16.66667, 'Not Admitted', 'AKWA IBOM', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IKA', '08066927143']
# add row successfully..........
# ==================================================
#               END MINING     No.   7
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210723543JF : index : 8
# ===================================================
# fetching content
# Surname :  Adejare-Bright
# Fist Name :  Oreoluwa
# Other Name :  Janet
# Telephone :  07059116480
# Registion Number :  202210723543JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210723543JF', 'Adejare-Bright Oreoluwa Janet', 'F', 'OYO', 239, 'Science Laboratory Technology', 53.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLUYOLE', '07059116480']
# add row successfully..........
# ==================================================
#               END MINING     No.   8
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211680502HA : index : 9
# ===================================================
# fetching content
# Surname :  Adekiigbe
# Fist Name :  Adedayo
# Other Name :  Mujeeb
# Telephone :  07044514912
# Registion Number :  202211680502HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211680502HA', 'Adekiigbe Adedayo Mujeeb', 'M', 'OSUN', 239, 'Business Administration & Management', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'AIYEDIRE', '07044514912']
# add row successfully..........
# ==================================================
#               END MINING     No.   9
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211039557GF : index : 10
# ===================================================
# fetching content
# Surname :  Abideen
# Fist Name :  Yakub
# Other Name :  Opeyemi
# Telephone :  07050376975
# Registion Number :  202211039557GF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211039557GF', 'Abideen Yakub Opeyemi', 'M', 'OSUN', 238, 'Electrical/Electronics Engineering', 43.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE-NORTH', '07050376975']
# add row successfully..........
# ==================================================
#               END MINING     No.   10
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211714146JF : index : 11
# ===================================================
# fetching content
# Surname :  Ayo
# Fist Name :  Michael
# Other Name :  Banlole
# Telephone :  07012961950
# Registion Number :  202211714146JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211714146JF', 'Ayo Michael Banlole', 'M', 'KOGI', 236, 'Office Technology & Management', 76.66667, 'Not Admitted', 'KOGI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'MOPA-MORO-MOPI', '07012961950']
# add row successfully..........
# ==================================================
#               END MINING     No.   11
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210000156JF : index : 12
# ===================================================
# fetching content
# Surname :  Orisajo
# Fist Name :  Favour
# Other Name :  Ayoola
# Telephone :  09078928210
# Registion Number :  202210000156JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210000156JF', 'Orisajo Favour Ayoola', 'M', 'OSUN', 236, 'Science Laboratory Technology', 40.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EJIGBO', '09078928210']
# add row successfully..........
# ==================================================
#               END MINING     No.   12
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211337050BF : index : 13
# ===================================================
# fetching content
# Surname :  Samuel
# Fist Name :  Esther
# Other Name :  Damilola
# Telephone :  07065984531
# Registion Number :  202211337050BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211337050BF', 'Samuel Esther Damilola', 'F', 'OYO', 236, 'Accountancy', 46.66667, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IBADAN SOUTH WEST', '07065984531']
# add row successfully..........
# ==================================================
#               END MINING     No.   13
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211209934EF : index : 14
# ===================================================
# fetching content
# Surname :  Abajesude
# Fist Name :  Gloria
# Other Name :  Adenike
# Telephone :  08130373651
# Registion Number :  202211209934EF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211209934EF', 'Abajesude Gloria Adenike', 'F', 'OSUN', 235, 'Computer Science', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EGBEDORE', '08130373651']
# add row successfully..........
# ==================================================
#               END MINING     No.   14
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210785916CA : index : 15
# ===================================================
# fetching content
# Surname :  Adewale
# Fist Name :  Uthman
# Other Name :  Olamilekan
# Telephone :  08139646729
# Registion Number :  202210785916CA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210785916CA', 'Adewale Uthman Olamilekan', 'M', 'OSUN', 234, 'Electrical/Electronics Engineering', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFELODUN', '08139646729']
# add row successfully..........
# ==================================================
#               END MINING     No.   15
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210164224IA : index : 16
# ===================================================
# fetching content
# Surname :  Kolawole
# Fist Name :  Opeyemi
# Other Name :  Abidemi
# Telephone :  08068798892
# Registion Number :  202210164224IA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210164224IA', 'Kolawole Opeyemi Abidemi', 'F', 'OSUN', 234, 'Science Laboratory Technology', 30.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE NORTH', '08068798892']
# add row successfully..........
# ==================================================
#               END MINING     No.   16
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210231325CA : index : 17
# ===================================================
# fetching content
# Surname :  Abiodun
# Fist Name :  Abdullahi
# Other Name :  Akinkunmi
# Telephone :  08147392726
# Registion Number :  202210231325CA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210231325CA', 'Abiodun Abdullahi Akinkunmi', 'M', 'OSUN', 234, 'Accountancy', 40.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ODO-OTIN', '08147392726']
# add row successfully..........
# ==================================================
#               END MINING     No.   17
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211609245BA : index : 18
# ===================================================
# fetching content
# Surname :  Jimoh
# Fist Name :  Teslim
# Other Name :  Omotayo
# Telephone :  07011598372
# Registion Number :  202211609245BA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211609245BA', 'Jimoh Teslim Omotayo', 'M', 'OYO', 232, 'Accountancy', 43.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OGBOMOSHO NORTH', '07011598372']
# add row successfully..........
# ==================================================
#               END MINING     No.   18
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210976173GF : index : 19
# ===================================================
# fetching content
# Surname :  Fajoye
# Fist Name :  Rachel
# Other Name :  Oluwaseyi
# Telephone :  08079765533
# Registion Number :  202210976173GF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210976173GF', 'Fajoye Rachel Oluwaseyi', 'F', 'OSUN', 232, 'Fashion Design & Clothing Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLORUNDA', '08079765533']
# add row successfully..........
# ==================================================
#               END MINING     No.   19
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211649055IA : index : 20
# ===================================================
# fetching content
# Surname :  Adewale
# Fist Name :  Sodiq
# Other Name :  Mayowa
# Telephone :  09134127985
# Registion Number :  202211649055IA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211649055IA', 'Adewale Sodiq Mayowa', 'M', 'OSUN', 232, 'Business Administration & Management', 43.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OSOGBO', '09134127985']
# add row successfully..........
# ==================================================
#               END MINING     No.   20
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210633420DA : index : 21
# ===================================================
# fetching content
# Surname :  Azeez
# Fist Name :  Monsuru
# Other Name :  Gbolahan
# Telephone :  09065861571
# Registion Number :  202210633420DA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210633420DA', 'Azeez Monsuru Gbolahan', 'M', 'OSUN', 231, 'Civil Engineering Technology', 43.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '09065861571']
# add row successfully..........
# ==================================================
#               END MINING     No.   21
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210177731JA : index : 22
# ===================================================
# fetching content
# Surname :  Oyelola
# Fist Name :  Funmilayo
# Other Name :  Elizabeth
# Telephone :  08168767954
# Registion Number :  202210177731JA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210177731JA', 'Oyelola Funmilayo Elizabeth', 'F', 'OYO', 231, 'Accountancy', 46.66667, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'AKINYELE', '08168767954']
# add row successfully..........
# ==================================================
#               END MINING     No.   22
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211676047CA : index : 23
# ===================================================
# fetching content
# Surname :  Agboola
# Fist Name :  Emmanuel
# Other Name :  Aduragbemi
# Telephone :  08168548507
# Registion Number :  202211676047CA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211676047CA', 'Agboola Emmanuel Aduragbemi', 'M', 'OSUN', 230, 'Science Laboratory Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '08168548507']
# add row successfully..........
# ==================================================
#               END MINING     No.   23
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210336879HA : index : 24
# ===================================================
# fetching content
# Surname :  Raji
# Fist Name :  Sulaiman
# Other Name :  Abiola
# Telephone :  07031533394
# Registion Number :  202210336879HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210336879HA', 'Raji Sulaiman Abiola', 'M', 'OYO', 230, 'Electrical/Electronics Engineering', 36.66667, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'AKINYELE', '07031533394']
# add row successfully..........
# ==================================================
#               END MINING     No.   24
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210978271CF : index : 25
# ===================================================
# fetching content
# Surname :  Taofeeq
# Fist Name :  Musa
# Other Name :  Olawale
# Telephone :  08069408294
# Registion Number :  202210978271CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210978271CF', 'Taofeeq Musa Olawale', 'M', 'OSUN', 230, 'Business Administration & Management', 60.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IWO', '08069408294']
# add row successfully..........
# ==================================================
#               END MINING     No.   25
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211473196FF : index : 26
# ===================================================
# fetching content
# Surname :  Ogunniyi
# Fist Name :  Ifeoluwa
# Other Name :  Eunice
# Telephone :  09022133687
# Registion Number :  202211473196FF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211473196FF', 'Ogunniyi Ifeoluwa Eunice', 'F', 'OSUN', 229, 'Statistics', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLORUNDA', '09022133687']
# add row successfully..........
# ==================================================
#               END MINING     No.   26
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211274348CF : index : 27
# ===================================================
# fetching content
# Surname :  Omidiora
# Fist Name :  Tobiloba
# Other Name :  Daniel
# Telephone :  08158550427
# Registion Number :  202211274348CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211274348CF', 'Omidiora Tobiloba Daniel', 'M', 'OSUN', 229, 'Hospitality Management', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE', '08158550427']
# add row successfully..........
# ==================================================
#               END MINING     No.   27
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210629504EA : index : 28
# ===================================================
# fetching content
# Surname :  Aderinto
# Fist Name :  Yusuff
# Other Name :  Ololade
# Telephone :  09155638039
# Registion Number :  202210629504EA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210629504EA', 'Aderinto Yusuff Ololade', 'M', 'OYO', 229, 'Civil Engineering Technology', 63.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLUYOLE', '09155638039']
# add row successfully..........
# ==================================================
#               END MINING     No.   28
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211606831BF : index : 29
# ===================================================
# fetching content
# Surname :  Omotosho
# Fist Name :  Opeyemi
# Other Name :  Ayomikun
# Telephone :  08055702252
# Registion Number :  202211606831BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211606831BF', 'Omotosho Opeyemi Ayomikun', 'M', 'ONDO', 228, 'Computer Science', 33.33333, 'Not Admitted', 'ONDO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFEDORE', '08055702252']
# add row successfully..........
# ==================================================
#               END MINING     No.   29
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211425165FA : index : 30
# ===================================================
# fetching content
# Surname :  Olajire
# Fist Name :  Semiu
# Other Name :  Abiodun
# Telephone :  09031477676
# Registion Number :  202211425165FA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211425165FA', 'Olajire Semiu Abiodun', 'M', 'OYO', 228, 'Accountancy', 50.0, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'LAGELU', '09031477676']
# add row successfully..........
# ==================================================
#               END MINING     No.   30
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210553270HA : index : 31
# ===================================================
# fetching content
# Surname :  Hussain
# Fist Name :  Zainab
# Other Name :  Fadekemi
# Telephone :  08064208932
# Registion Number :  202210553270HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210553270HA', 'Hussain Zainab Fadekemi', 'F', 'OSUN', 227, 'Nutrition & Dietetics', 60.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '08064208932']
# add row successfully..........
# ==================================================
#               END MINING     No.   31
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210503824BF : index : 32
# ===================================================
# fetching content
# Surname :  Muhammadjamiu
# Fist Name :  Mardiyyah
# Other Name :  Tinuke
# Telephone :  08146499421
# Registion Number :  202210503824BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210503824BF', 'Muhammadjamiu Mardiyyah Tinuke', 'F', 'OSUN', 227, 'Nutrition & Dietetics', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFELODUN', '08146499421']
# add row successfully..........
# ==================================================
#               END MINING     No.   32
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210516167FA : index : 33
# ===================================================
# fetching content
# Surname :  Bamiwuye
# Fist Name :  Tosin
# Other Name :  Mary
# Telephone :  09161145261
# Registion Number :  202210516167FA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210516167FA', 'Bamiwuye Tosin Mary', 'F', 'OSUN', 226, 'Accountancy', 53.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE', '09161145261']
# add row successfully..........
# ==================================================
#               END MINING     No.   33
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210128239HF : index : 34
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   34
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210874860JA : index : 35
# ===================================================
# fetching content
# Surname :  Hamzat
# Fist Name :  Idris
# Other Name :  Opeyemi
# Telephone :  08128099737
# Registion Number :  202210874860JA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210874860JA', 'Hamzat Idris Opeyemi', 'M', 'OSUN', 226, 'Science Laboratory Technology', 46.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE-NORTH', '08128099737']
# add row successfully..........
# ==================================================
#               END MINING     No.   35
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211073986GA : index : 36
# ===================================================
# fetching content
# Surname :  Obialor
# Fist Name :  Amarachi
# Other Name :  Prisca
# Telephone :  08141627919
# Registion Number :  202211073986GA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211073986GA', 'Obialor Amarachi Prisca', 'F', 'ANAMBRA', 225, 'Banking & Finance', 46.66667, 'Not Admitted', 'ANAMBRA', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IHIALA', '08141627919']
# add row successfully..........
# ==================================================
#               END MINING     No.   36
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211261211GF : index : 37
# ===================================================
# fetching content
# Surname :  Akanni
# Fist Name :  Balikis
# Other Name :  Olabisi
# Telephone :  07064449312
# Registion Number :  202211261211GF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211261211GF', 'Akanni Balikis Olabisi', 'F', 'OSUN', 225, 'Computer Engineering', 33.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '07064449312']
# add row successfully..........
# ==================================================
#               END MINING     No.   37
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210448893CF : index : 38
# ===================================================
# fetching content
# Surname :  Aina
# Fist Name :  Oluwajomiloju
# Other Name :  Moyosore
# Telephone :  08066449517
# Registion Number :  202210448893CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210448893CF', 'Aina Oluwajomiloju Moyosore', 'F', 'EKITI', 225, 'Science Laboratory Technology', 50.0, 'Not Admitted', 'EKITI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ILEJEMEJE', '08066449517']
# add row successfully..........
# ==================================================
#               END MINING     No.   38
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210018629HA : index : 39
# ===================================================
# fetching content
# Surname :  Shuaib
# Fist Name :  Aminat
# Other Name :  Oyinoza
# Telephone :  08163835935
# Registion Number :  202210018629HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210018629HA', 'Shuaib Aminat Oyinoza', 'F', 'KOGI', 225, 'Computer Science', 70.0, 'Not Admitted', 'KOGI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OKENE', '08163835935']
# add row successfully..........
# ==================================================
#               END MINING     No.   39
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211033263JA : index : 40
# ===================================================
# fetching content
# Surname :  Oni
# Fist Name :  Opeyemi
# Other Name :  Precious
# Telephone :  09026824120
# Registion Number :  202211033263JA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211033263JA', 'Oni Opeyemi Precious', 'F', 'OSUN', 224, 'Office Technology & Management', 26.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE', '09026824120']
# add row successfully..........
# ==================================================
#               END MINING     No.   40
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211340183CF : index : 41
# ===================================================
# fetching content
# Surname :  Popoola
# Fist Name :  Ayodele
# Other Name :  Abdul-Rahman
# Telephone :  08061134666
# Registion Number :  202211340183CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211340183CF', 'Popoola Ayodele Abdul-Rahman', 'M', 'OSUN', 224, 'Architectural Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ODO-OTIN', '08061134666']
# add row successfully..........
# ==================================================
#               END MINING     No.   41
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211211312JA : index : 42
# ===================================================
# fetching content
# Surname :  Alabi
# Fist Name :  Oreoluwa
# Other Name :  Dorcas
# Telephone :  09158269142
# Registion Number :  202211211312JA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211211312JA', 'Alabi Oreoluwa Dorcas', 'F', 'EKITI', 224, 'Horticultural Technology', nan, 'Not Admitted', 'EKITI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IKERE', '09158269142']
# add row successfully..........
# ==================================================
#               END MINING     No.   42
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210684181GF : index : 43
# ===================================================
# fetching content
# Surname :  Oyeniyi
# Fist Name :  Anjolaoluwa
# Other Name :  Mary
# Telephone :  08088533860
# Registion Number :  202210684181GF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210684181GF', 'Oyeniyi Anjolaoluwa Mary', 'F', 'OSUN', 224, 'Nutrition & Dietetics', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'BOLUWADURO', '08088533860']
# add row successfully..........
# ==================================================
#               END MINING     No.   43
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211224667AF : index : 44
# ===================================================
# fetching content
# Surname :  Tijani
# Fist Name :  Ibrahim
# Other Name :  Adekunle
# Telephone :  07047401755
# Registion Number :  202211224667AF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211224667AF', 'Tijani Ibrahim Adekunle', 'M', 'OYO', 224, 'Mechanical Engineering Technology', 40.0, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OYO-EAST', '07047401755']
# add row successfully..........
# ==================================================
#               END MINING     No.   44
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210501914GF : index : 45
# ===================================================
# fetching content
# Surname :  Dada
# Fist Name :  Iyanuoluwa
# Other Name :  Omotayo
# Telephone :  07055193564
# Registion Number :  202210501914GF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210501914GF', 'Dada Iyanuoluwa Omotayo', 'F', 'EKITI', 223, 'Nutrition & Dietetics', 50.0, 'Not Admitted', 'EKITI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EFON', '07055193564']
# add row successfully..........
# ==================================================
#               END MINING     No.   45
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211100225GA : index : 46
# ===================================================
# fetching content
# Surname :  Asimi
# Fist Name :  Nasirullahi
# Other Name :  Olamilekan
# Telephone :  09036292561
# Registion Number :  202211100225GA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211100225GA', 'Asimi Nasirullahi Olamilekan', 'M', 'OSUN', 223, 'Science Laboratory Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE-NORTH', '09036292561']
# add row successfully..........
# ==================================================
#               END MINING     No.   46
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211312726DF : index : 47
# ===================================================
# fetching content
# Surname :  Kehinde
# Fist Name :  Khadijah
# Other Name :  Romoke
# Telephone :  08128026840
# Registion Number :  202211312726DF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211312726DF', 'Kehinde Khadijah Romoke', 'F', 'OSUN', 223, 'Library & Information Science', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLORUNDA', '08128026840']
# add row successfully..........
# ==================================================
#               END MINING     No.   47
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210712269DF : index : 48
# ===================================================
# fetching content
# Surname :  Adegoke
# Fist Name :  Taiwo
# Other Name :  Oladipupo
# Telephone :  09073594716
# Registion Number :  202210712269DF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210712269DF', 'Adegoke Taiwo Oladipupo', 'M', 'OSUN', 222, 'Quantity Surveying', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '09073594716']
# add row successfully..........
# ==================================================
#               END MINING     No.   48
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210568227FA : index : 49
# ===================================================
# fetching content
# Surname :  Bolarinwa
# Fist Name :  Adewale
# Other Name :  Moses
# Telephone :  09024939919
# Registion Number :  202210568227FA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210568227FA', 'Bolarinwa Adewale Moses', 'M', 'EKITI', 222, 'Business Administration & Management', 30.0, 'Not Admitted', 'EKITI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EFON', '09024939919']
# add row successfully..........
# ==================================================
#               END MINING     No.   49
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210672870JF : index : 50
# ===================================================
# fetching content
# Surname :  Fadeyi
# Fist Name :  Temitope
# Other Name :  Rachael
# Telephone :  09019068415
# Registion Number :  202210672870JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210672870JF', 'Fadeyi Temitope Rachael', 'F', 'OYO', 222, 'Accountancy', 20.0, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EGBEDA', '09019068415']
# add row successfully..........
# ==================================================
#               END MINING     No.   50
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210790384AF : index : 51
# ===================================================
# fetching content
# Surname :  Akinwande
# Fist Name :  Esther
# Other Name :  Olajumoke
# Telephone :  09124708340
# Registion Number :  202210790384AF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210790384AF', 'Akinwande Esther Olajumoke', 'F', 'OGUN', 221, 'Library & Information Science', nan, 'Not Admitted', 'OGUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OBAFEMI-OWODE', '09124708340']
# add row successfully..........
# ==================================================
#               END MINING     No.   51
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210604332CF : index : 52
# ===================================================
# fetching content
# Surname :  Odekanle
# Fist Name :  Boluwatife
# Other Name :  Florence
# Telephone :  08113763759
# Registion Number :  202210604332CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210604332CF', 'Odekanle Boluwatife Florence', 'F', 'OSUN', 221, 'Science Laboratory Technology', 36.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '08113763759']
# add row successfully..........
# ==================================================
#               END MINING     No.   52
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210997348CA : index : 53
# ===================================================
# fetching content
# Surname :  Akande
# Fist Name :  Taiwo
# Other Name :  Olatunde
# Telephone :  08103811484
# Registion Number :  202210997348CA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210997348CA', 'Akande Taiwo Olatunde', 'M', 'OYO', 221, 'Business Administration & Management', 46.66667, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLUYOLE', '08103811484']
# add row successfully..........
# ==================================================
#               END MINING     No.   53
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211654089IF : index : 54
# ===================================================
# fetching content
# Surname :  Ajayi
# Fist Name :  Oyedeji
# Other Name :  Cephas
# Telephone :  08143890720
# Registion Number :  202211654089IF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211654089IF', 'Ajayi Oyedeji Cephas', 'M', 'ONDO', 220, 'Science Laboratory Technology', 36.66667, 'Not Admitted', 'ONDO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'AKURE', '08143890720']
# add row successfully..........
# ==================================================
#               END MINING     No.   54
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211331944IF : index : 55
# ===================================================
# fetching content
# Surname :  Alabi
# Fist Name :  Esther
# Other Name :  Ifeoluwa
# Telephone :  08143077858
# Registion Number :  202211331944IF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211331944IF', 'Alabi Esther Ifeoluwa', 'F', 'OSUN', 220, 'Fashion Design & Clothing Technology', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IREWOLE', '08143077858']
# add row successfully..........
# ==================================================
#               END MINING     No.   55
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210516428HF : index : 56
# ===================================================
# fetching content
# Surname :  Olatunji
# Fist Name :  Joseph
# Other Name :  Adekunmi
# Telephone :  08059965999
# Registion Number :  202210516428HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210516428HF', 'Olatunji Joseph Adekunmi', 'M', 'OSUN', 220, 'Electrical/Electronics Engineering', 40.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EGBEDORE', '08059965999']
# add row successfully..........
# ==================================================
#               END MINING     No.   56
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211322965EF : index : 57
# ===================================================
# fetching content
# Surname :  Alex
# Fist Name :  Victor
# Other Name :  Chukwuemeka
# Telephone :  07025242467
# Registion Number :  202211322965EF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211322965EF', 'Alex Victor Chukwuemeka', 'M', 'IMO', 220, 'Electrical/Electronics Engineering', nan, 'Not Admitted', 'IMO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'MBAITOLI', '07025242467']
# add row successfully..........
# ==================================================
#               END MINING     No.   57
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211192372HF : index : 58
# ===================================================
# fetching content
# Surname :  Kehinde
# Fist Name :  Kemisola
# Other Name :  Anuoluwa
# Telephone :  07046196216
# Registion Number :  202211192372HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211192372HF', 'Kehinde Kemisola Anuoluwa', 'F', 'OSUN', 220, 'Banking & Finance', 36.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '07046196216']
# add row successfully..........
# ==================================================
#               END MINING     No.   58
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210880393HA : index : 59
# ===================================================
# fetching content
# Surname :  Adeosun
# Fist Name :  Blessing
# Other Name :  Abiodun
# Telephone :  08053264908
# Registion Number :  202210880393HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210880393HA', 'Adeosun Blessing Abiodun', 'F', 'OSUN', 220, 'Nutrition & Dietetics', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EGBEDORE', '08053264908']
# add row successfully..........
# ==================================================
#               END MINING     No.   59
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210207725DA : index : 60
# ===================================================
# fetching content
# Surname :  Olabimtan
# Fist Name :  Oluwasegun
# Other Name :  Oladotun
# Telephone :  08165033946
# Registion Number :  202210207725DA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210207725DA', 'Olabimtan Oluwasegun Oladotun', 'M', 'OYO', 220, 'Civil Engineering Technology', 43.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ATIBA', '08165033946']
# add row successfully..........
# ==================================================
#               END MINING     No.   60
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210081490CF : index : 61
# ===================================================
# fetching content
# Surname :  Mutair
# Fist Name :  Barakat
# Other Name :  Folashade
# Telephone :  08106038665
# Registion Number :  202210081490CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210081490CF', 'Mutair Barakat Folashade', 'F', 'OSUN', 220, 'Hospitality Management', 43.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE', '08106038665']
# add row successfully..........
# ==================================================
#               END MINING     No.   61
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211226952HF : index : 62
# ===================================================
# fetching content
# Surname :  Raji
# Fist Name :  Abdulbasit
# Other Name :  Olasunkanmi
# Telephone :  08162662357
# Registion Number :  202211226952HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211226952HF', 'Raji Abdulbasit Olasunkanmi', 'M', 'OSUN', 219, 'Electrical/Electronics Engineering', 46.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ISOKAN', '08162662357']
# add row successfully..........
# ==================================================
#               END MINING     No.   62
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210615513HF : index : 63
# ===================================================
# fetching content
# Surname :  Akande
# Fist Name :  Ifeoluwa
# Other Name :  Emmanuel
# Telephone :  07012757484
# ...
# ['202210506022EF', 'Hassan Hakimot Olaitan', 'F', 'OSUN', 190, 'Science Laboratory Technology', 73.33333, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EDE-NORTH', '09035704919']
# add row successfully..........
# ==================================================
#               END MINING     No.   617
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210684518JA : index : 618
# ===================================================
# fetching content
# Surname :  Mojeed
# Fist Name :  Sukroh
# Other Name :  Omobonike
# Telephone :  08110255747
# Registion Number :  202210684518JA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210684518JA', 'Mojeed Sukroh Omobonike', 'F', 'OYO', 190, 'Nutrition & Dietetics', 33.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OLUYOLE', '08110255747']
# add row successfully..........
# ==================================================
#               END MINING     No.   618
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210674822CF : index : 619
# ===================================================
# fetching content
# Surname :  Alabi
# Fist Name :  Adebayo
# Other Name :  Emmanuel
# Telephone :  09161765899
# Registion Number :  202210674822CF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210674822CF', 'Alabi Adebayo Emmanuel', 'M', 'OSUN', 190, 'Library & Information Science', 30.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IWO', '09161765899']
# add row successfully..........
# ==================================================
#               END MINING     No.   619
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210944399JF : index : 620
# ===================================================
# fetching content
# Surname :  Adeleke
# Fist Name :  Oluwatosin
# Other Name :  Esther
# Telephone :  08106427696
# Registion Number :  202210944399JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210944399JF', 'Adeleke Oluwatosin Esther', 'F', 'OYO', 190, 'Business Administration & Management', 50.0, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'SAKI-WEST', '08106427696']
# add row successfully..........
# ==================================================
#               END MINING     No.   620
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211481936FF : index : 621
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   621
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211230949EA : index : 622
# ===================================================
# fetching content
# Surname :  Adams
# Fist Name :  Omotolani
# Other Name :  Aishat
# Telephone :  08085787372
# Registion Number :  202211230949EA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211230949EA', 'Adams Omotolani Aishat', 'F', 'LAGOS', 190, 'Science Laboratory Technology', 40.0, 'Not Admitted', 'LAGOS', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'AMUWO-ODOFIN', '08085787372']
# add row successfully..........
# ==================================================
#               END MINING     No.   622
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211516926JF : index : 623
# ===================================================
# fetching content
# Surname :  Eluyinka
# Fist Name :  Bukunmi
# Other Name :  Ayomide
# Telephone :  07069670967
# Registion Number :  202211516926JF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211516926JF', 'Eluyinka Bukunmi Ayomide', 'M', 'OSUN', 190, 'Library & Information Science', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE-EAST', '07069670967']
# add row successfully..........
# ==================================================
#               END MINING     No.   623
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210168987BF : index : 624
# ===================================================
# fetching content
# Surname :  Adeleke
# Fist Name :  Azeez
# Other Name :  Olamilekan
# Telephone :  07046344095
# Registion Number :  202210168987BF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210168987BF', 'Adeleke Azeez Olamilekan', 'M', 'OSUN', 190, 'Computer Science', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IWO', '07046344095']
# add row successfully..........
# ==================================================
#               END MINING     No.   624
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210856075GA : index : 625
# ===================================================
# fetching content
# Surname :  Ganiyu
# Fist Name :  Oluwatobi
# Other Name :  Michael
# Telephone :  09159169676
# Registion Number :  202210856075GA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210856075GA', 'Ganiyu Oluwatobi Michael', 'M', 'OSUN', 190, 'Science Laboratory Technology', 30.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EJIGBO', '09159169676']
# add row successfully..........
# ==================================================
#               END MINING     No.   625
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210883549GA : index : 626
# ===================================================
# fetching content
# Surname :  Taiwo
# Fist Name :  Seyi
# Other Name :  Joshua
# Telephone :  08160523237
# Registion Number :  202210883549GA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210883549GA', 'Taiwo Seyi Joshua', 'M', 'OYO', 190, 'Science Laboratory Technology', 63.33333, 'Not Admitted', 'OYO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ONA-ARA', '08160523237']
# add row successfully..........
# ==================================================
#               END MINING     No.   626
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211189237HF : index : 627
# ===================================================
# fetching content
# Surname :  Adesola
# Fist Name :  Mariam
# Other Name :  Adeola
# Telephone :  08050272636
# Registion Number :  202211189237HF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211189237HF', 'Adesola Mariam Adeola', 'F', 'OSUN', 190, 'Business Administration & Management', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ILA', '08050272636']
# add row successfully..........
# ==================================================
#               END MINING     No.   627
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211040930EA : index : 628
# ===================================================
# fetching content
# Surname :  Obi
# Fist Name :  Folasewa
# Other Name :  Oluwatoyin
# Telephone :  09124590124
# Registion Number :  202211040930EA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211040930EA', 'Obi Folasewa Oluwatoyin', 'F', 'OSUN', 190, 'Science Laboratory Technology', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OROLU', '09124590124']
# add row successfully..........
# ==================================================
#               END MINING     No.   628
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211595204BA : index : 629
# ===================================================
# fetching content
# Surname :  Adesoro
# Fist Name :  Miracle
# Other Name :  Emmanuel
# Telephone :  08110832869
# Registion Number :  202211595204BA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211595204BA', 'Adesoro Miracle Emmanuel', 'M', 'OSUN', 190, 'Marketing', nan, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IREWOLE', '08110832869']
# add row successfully..........
# ==================================================
#               END MINING     No.   629
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211039827EF : index : 630
# ===================================================
# fetching content
# Surname :  Ajiboso
# Fist Name :  Mayowa
# Other Name :  Oluwasegun
# Telephone :  07040310386
# Registion Number :  202211039827EF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211039827EF', 'Ajiboso Mayowa Oluwasegun', 'M', 'OSUN', 190, 'Civil Engineering Technology', 36.66667, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ODO-OTIN', '07040310386']
# add row successfully..........
# ==================================================
#               END MINING     No.   630
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210556145EA : index : 631
# ===================================================
# fetching content
# Surname :  Iroegbu
# Fist Name :  Micheal
# Other Name :  Elijah
# Telephone :  09079498915
# Registion Number :  202210556145EA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210556145EA', 'Iroegbu Micheal Elijah', 'M', 'IMO', 190, 'Science Laboratory Technology', 60.0, 'Not Admitted', 'IMO', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'ORLU', '09079498915']
# add row successfully..........
# ==================================================
#               END MINING     No.   631
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210903619DA : index : 632
# ===================================================
# fetching content
# Surname :  Adebayo
# Fist Name :  Idris
# Other Name :  Adigun
# Telephone :  08167939275
# Registion Number :  202210903619DA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210903619DA', 'Adebayo Idris Adigun', 'M', 'OSUN', 190, 'Mechanical Engineering Technology', 50.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'OSOGBO', '08167939275']
# add row successfully..........
# ==================================================
#               END MINING     No.   632
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202211039162EF : index : 633
# ===================================================
# fetching content
# Surname :  Elubode
# Fist Name :  Michael
# Other Name :  Olamilekan
# Telephone :  08084031968
# Registion Number :  202211039162EF
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202211039162EF', 'Elubode Michael Olamilekan', 'M', 'OSUN', 190, 'Library & Information Science', 40.0, 'Not Admitted', 'OSUN', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'IFE', '08084031968']
# add row successfully..........
# ==================================================
#               END MINING     No.   633
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210697689HA : index : 634
# ===================================================
# fetching content
# Surname :  Yaya
# Fist Name :  Razaq
# Other Name :  Olamide
# Telephone :  08071845948
# Registion Number :  202210697689HA
# IS VALID ?  True
#                      STUDENT CONFIRMED...
# ['202210697689HA', 'Yaya Razaq Olamide', 'M', 'EKITI', 190, 'Quantity Surveying', 40.0, 'Not Admitted', 'EKITI', 'FEDERAL POLYTECHNIC, EDE, OSUN STATE', 'EKITI-WEST', '08071845948']
# add row successfully..........
# ==================================================
#               END MINING     No.   634
# ==================================================
#
# ==== SOURCE FILE SIZE IS ==>  6266
# ===================================================
#    START MINING   FOR :  202210715513GA : index : 635
# ===================================================
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In [4], line 54
#      51 print(f'   START MINING   FOR :  {reg} : index : {index}  ')
#      52 print('===================================================')
# ---> 54 data , lenght = fetch_info(reg)
#      55 if lenght != 0 :
#      56
#      57     # printing data for confirmation
#      58     try:
#
# Cell In [4], line 14, in fetch_info(reg_number)
#      13 def fetch_info(reg_number):
# ---> 14     driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip')
#      15     reg = driver.find_element('id' , "txtRegNumber")
#      16     reg.send_keys(reg_number)
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 299.760
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0050F243]
# 	(No symbol) [0x00497FD1]
# 	(No symbol) [0x0038D04D]
# 	(No symbol) [0x0037FC24]
# 	(No symbol) [0x0037FA5C]
# 	(No symbol) [0x0037E7E8]
# 	(No symbol) [0x0037EEF7]
# 	(No symbol) [0x00387F08]
# 	(No symbol) [0x00393455]
# 	(No symbol) [0x00396766]
# 	(No symbol) [0x0037F2A1]
# 	(No symbol) [0x0039328F]
# 	(No symbol) [0x003ECDCE]
# 	(No symbol) [0x003D8386]
# 	(No symbol) [0x003B163C]
# 	(No symbol) [0x003B269D]
# 	GetHandleVerifier [0x007A9A22+2655074]
# 	GetHandleVerifier [0x0079CA24+2601828]
# 	GetHandleVerifier [0x005B8C0A+619850]
# 	GetHandleVerifier [0x005B7830+614768]
# 	(No symbol) [0x004A05FC]
# 	(No symbol) [0x004A5968]
# 	(No symbol) [0x004A5A55]
# 	(No symbol) [0x004B051B]
# 	BaseThreadInitThunk [0x76146BD9+25]
# 	RtlGetFullPathName_UEx [0x779C8FD2+1218]
# 	RtlGetFullPathName_UEx [0x779C8F9D+1165]

# %%
# 2182

# %%
import pandas as pd 
import os

data = pd.read_csv('pool_ekiti/foye_gen1.csv')
data.shape

# def pd_tuple(dataframe):
    
#     for index in range(len(dataframe)):
#         tup_list = tuple(data.iloc[index].values)
        
#         return tup_list
