# %%
#     =====================================================================================   #
#                                       FIRST SECTION CODE                                    #
#     =====================================================================================   #

# IMPORTING IMPORTANT MODULE..... 
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pandas as pd

# IMPORTING ORIGINAL DATA 
jamb_data = pd.read_csv('Newrecord/kwasufile.csv')

# GETTING ATTRIBUTE FROM ORIGINAL DATA
candidate_name = jamb_data["RG_CANDNAME"].values
candidate_reg = jamb_data["RG_NUM"].values
names = list(candidate_name)
regs = list(candidate_reg)

# print(names)
# print(regs)

# GENERATING NEW DATAFRAME
gen_df = pd.DataFrame()
    
try:
    gen_df = pd.read_csv('Newrecord/kwasu_gen/kwasufile_gen2.csv', index=False)
except Exception: 
    pass

def create_dataframe(dataframe,  add=''):
    attributes = []

    for attr in dataframe.columns: 
        attributes.append(attr)
    if add != '':
        attributes.append(add)

    df = pd.DataFrame([] , columns=attributes)

    return df , attributes


if gen_df.empty:
    print('original data is empty')
    gen_df , _ = create_dataframe(jamb_data, 'Contact')

else: 
    pass
# Out:
# original data is empty

# %%
#     =====================================================================================   #
#                                HELPER METHOD FOR SECTION TWO                                #
#     =====================================================================================   #




# helper method to valide content compatibility 

def check_content_matching(o_reg='data_reg' , o_name='d_name' , m_reg='mine_reg' , m_name = 'm_name'): 
    
    #   : o_reg / the import jamb student registration number 
    #   : o_name / the import jamb student name 
    #   : m_reg / the mined student registration number 
    #   : m_name / the mined student name 

    validate = False 
    if (m_reg.upper().strip() == o_reg.upper().strip() and m_name.lower() in o_name.lower().split()):
        validate = True
    else : 
        validate = False
    return validate ; 

# helper method to had new row to the new table
def add_row(old_table , new_table, tel='',  m_reg = ''):
    
    if m_reg != '':
        d = old_table[old_table[old_table.columns[0]] == m_reg]
        old_val = d.values
#         print(old_val.flatten())
        temp_value = []
        for value in list(old_val.flatten()):
            temp_value.append(value)

#         print('TEL:' , tel)

        if tel != '':
            temp_value.append(str(tel))
            
            print(temp_value)
            new_table.loc[len(new_table)] = temp_value
            
            new_table.to_csv('Newrecord/kwasu_gen/kwasufile_gen2.csv')
            print('Row addes successfully.....')

            return new_table
                
# add_row(jamb_data, gen_df , tel, reg_number)

# %%
#     =====================================================================================   #
#                                       SECOND SECTION CODE                                   #
#     =====================================================================================   #

# eporting to json 

#  to json ...
import json as j




# NAVIGATING THE WEB BROWSER USING THE STUDENT REGISTRATION NUMBER

driver= webdriver.Chrome()

def fetch_info(reg_number):
    driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip') 
    reg = driver.find_element('id' , "txtRegNumber")
    reg.send_keys(reg_number)

    # submitting form
    # reg.submit()
    sb = driver.find_element('id' , "lnkSearch")

    sb.click()
    # driver.refresh()
    # print('WEB PAGE ', driver.current_url)


    # getting data from html document
    print('fetching content')
    url = f'https://efacility.jamb.gov.ng/TempFiles/Main_Examination_Slip_{reg_number}.htm'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    data = soup.find_all('label')

    return data , len(data)


#  scraping through web for contact 

for index in range(6416  , len(regs)):
    reg = regs[index]
    name = names[index]
      
    
#         with  open('reg_cache.json','w') as file:  
#             file.dump({'last_reg':reg ,  'last_name':name , 'index':index})

    print()
    print(f'========== SOURCE FILE SIZE IS ==>  {jamb_data.shape[0]}')
    print('===================================================')
    print(f'   START MINING   FOR :  {reg} : index : {index}  ')
    print('===================================================')

    data , lenght = fetch_info(reg)
    if lenght != 0 :
            
        # printing data for confirmation
        try:
            surname = data[1].get_text()
            firstname = data[2].get_text()
            othername = data[4].get_text()
            tel = data[12].get_text()
            reg_number = data[15].get_text()

            print('Surname : ' , surname)
            print('Fist Name : ', firstname)
            print('Other Name : ',  othername)
            print('Telephone : ' , tel)
            print('Registion Number : ' , reg_number)


        

            valid = check_content_matching(reg, name , reg_number, surname)
            print('VALID : ', valid)

            if valid :
                print('                     STUDENT CONFIRMED... ')
                add_row(jamb_data, gen_df , tel, reg_number)
                
        except Exception:
            print('error')
                  
    print('==================================================')
    print(f'              END MINING     No.   {index}       ')
    print('==================================================')
        
        
    
            
            

        
print('==================================================')
print(f'               FINAL END OF MINING               ')
print('==================================================')
# Out:
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210517121DA : index : 6416
# ===================================================
# fetching content
# Surname :  Ogunkorode
# Fist Name :  Modupe
# Other Name :  Tobiloba
# Telephone :  08108834809
# Registion Number :  202210517121DA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210517121DA', 'Ogunkorode Modupe Tobiloba', 'F', 'EKITI', 189, 'Linguistics', nan, 'Not Admitted', 'EKITI', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'AIYEKIRE', '08108834809']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6416
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211667693IF : index : 6417
# ===================================================
# fetching content
# Surname :  Lawal
# Fist Name :  Jamiu
# Other Name :  Omogbolahan
# Telephone :  08125254129
# Registion Number :  202211667693IF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211667693IF', 'Lawal Jamiu Omogbolahan', 'M', 'KWARA', 189, 'Computer Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYUN', '08125254129']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6417
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211405658CA : index : 6418
# ===================================================
# fetching content
# Surname :  Adetunji
# Fist Name :  Mobolaji
# Other Name :  Emmanuel
# Telephone :  08073768537
# Registion Number :  202211405658CA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211405658CA', 'Adetunji Mobolaji Emmanuel', 'M', 'KWARA', 189, 'Civil Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OFFA', '08073768537']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6418
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211615007IA : index : 6419
# ===================================================
# fetching content
# Surname :  Badmus
# Fist Name :  Arafat
# Other Name :  Kofoworola
# Telephone :  08104846156
# Registion Number :  202211615007IA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211615007IA', 'Badmus Arafat Kofoworola', 'F', 'KWARA', 189, 'Public Health Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IREPODUN', '08104846156']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6419
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210258931CF : index : 6420
# ===================================================
# fetching content
# Surname :  Lawal
# Fist Name :  Rofiat
# Other Name :  Olaide
# Telephone :  08118184455
# Registion Number :  202210258931CF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210258931CF', 'Lawal Rofiat Olaide', 'F', 'OYO', 189, 'Linguistics', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'AKINYELE', '08118184455']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6420
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210511591DF : index : 6421
# ===================================================
# fetching content
# Surname :  Anifowose
# Fist Name :  Mubarak
# Other Name :  Martins
# Telephone :  07056239142
# Registion Number :  202210511591DF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210511591DF', 'Anifowose Mubarak Martins', 'M', 'ONDO', 189, 'Mechanical Engineering', nan, 'Not Admitted', 'ONDO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'AKOKO-SOUTH', '07056239142']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6421
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210055842BF : index : 6422
# ===================================================
# fetching content
# Surname :  Abdulmalik
# Fist Name :  Mercy
# Other Name :  Femi
# Telephone :  08070931201
# Registion Number :  202210055842BF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210055842BF', 'Abdulmalik Mercy Femi', 'M', 'KOGI', 189, 'Mass Communication', nan, 'Not Admitted', 'KOGI', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OKENE', '08070931201']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6422
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210648809DF : index : 6423
# ===================================================
# fetching content
# Surname :  Alabi
# Fist Name :  Mubarak
# Other Name :  Opeyemi
# Telephone :  09030260634
# Registion Number :  202210648809DF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210648809DF', 'Alabi Mubarak Opeyemi', 'M', 'KWARA', 189, 'Environmental Management & Toxicology', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IREPODUN', '09030260634']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6423
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210909968BF : index : 6424
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   6424
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210248554EA : index : 6425
# ===================================================
# fetching content
# Surname :  Olanrewaju
# Fist Name :  Olalekan
# Other Name :  Saoban
# Telephone :  08180362303
# Registion Number :  202210248554EA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210248554EA', 'Olanrewaju Olalekan Saoban', 'M', 'KWARA', 189, 'Economics', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-EAST', '08180362303']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6425
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210832956EA : index : 6426
# ===================================================
# fetching content
# Surname :  Abdulkadri-Aliyu
# Fist Name :  Fatimah
# Other Name :
# Telephone :  08067223657
# Registion Number :  202210832956EA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210832956EA', 'Abdulkadri-Aliyu Fatimah', 'F', 'KWARA', 189, 'Microbiology', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-EAST', '08067223657']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6426
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210995753BF : index : 6427
# ===================================================
# fetching content
# Surname :  Ibrahim
# Fist Name :  Shuiabat
# Other Name :  Ayoola
# Telephone :  08173255514
# Registion Number :  202210995753BF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210995753BF', 'Ibrahim Shuiabat Ayoola', 'F', 'KWARA', 189, 'Environmental Health Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-SOUTH', '08173255514']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6427
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210147787JA : index : 6428
# ===================================================
# fetching content
# Surname :  Ojubanire
# Fist Name :  Sahadat
# Other Name :  Damilola
# Telephone :  08028374360
# Registion Number :  202210147787JA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210147787JA', 'Ojubanire Sahadat Damilola', 'F', 'OYO', 189, 'Accounting', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'SAKI-WEST', '08028374360']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6428
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210452037HF : index : 6429
# ===================================================
# fetching content
# Surname :  Afolabi
# Fist Name :  Abdulmuiz
# Other Name :  Bolaji
# Telephone :  09042706127
# Registion Number :  202210452037HF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210452037HF', 'Afolabi Abdulmuiz Bolaji', 'M', 'KWARA', 189, 'Computer Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IREPODUN', '09042706127']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6429
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210073118IF : index : 6430
# ===================================================
# fetching content
# Surname :  Oladiran
# Fist Name :  Oluwapelumi
# Other Name :  Victor
# Telephone :  07014123026
# Registion Number :  202210073118IF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210073118IF', 'Oladiran Oluwapelumi Victor', 'M', 'OSUN', 189, 'Computer Science', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OSOGBO', '07014123026']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6430
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210983128GA : index : 6431
# ===================================================
# fetching content
# Surname :  Ogbeche
# Fist Name :  Alice
# Other Name :  Ochanyan
# Telephone :  09039628771
# Registion Number :  202210983128GA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210983128GA', 'Ogbeche Alice Ochanyan', 'F', 'BENUE', 189, 'Public Health Science', nan, 'Not Admitted', 'BENUE', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OGBADIBO', '09039628771']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6431
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211192598IF : index : 6432
# ===================================================
# fetching content
# Surname :  Olarinoye
# Fist Name :  Mahabbah
# Other Name :  Oluwatobiloba
# Telephone :  07033974013
# Registion Number :  202211192598IF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211192598IF', 'Olarinoye Mahabbah Oluwatobiloba', 'F', 'KWARA', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OFFA', '07033974013']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6432
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211386198EA : index : 6433
# ===================================================
# fetching content
# Surname :  Gobir
# Fist Name :  Halimah
# Other Name :
# Telephone :  08132035089
# Registion Number :  202211386198EA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211386198EA', 'Gobir Halimah', 'F', 'KWARA', 189, 'Mass Communication', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-WEST', '08132035089']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6433
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211259672GF : index : 6434
# ===================================================
# fetching content
# Surname :  Aina
# Fist Name :  Zainab
# Other Name :  Olamide
# Telephone :  09090432343
# Registion Number :  202211259672GF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211259672GF', 'Aina Zainab Olamide', 'F', 'OSUN', 189, 'Library & Information Science', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ODO-OTIN', '09090432343']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6434
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210203959FA : index : 6435
# ===================================================
# fetching content
# Surname :  Raji
# Fist Name :  Fuad
# Other Name :  Olatokumbo
# Telephone :  08162131463
# Registion Number :  202210203959FA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210203959FA', 'Raji Fuad Olatokumbo', 'M', 'KADUNA', 189, 'Electrical /Electronics Engineering', nan, 'Not Admitted', 'KADUNA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'KADUNA-NORTH', '08162131463']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6435
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210268357BF : index : 6436
# ===================================================
# fetching content
# Surname :  Akangbe
# Fist Name :  Faheedat
# Other Name :  Temitope
# Telephone :  08083062840
# Registion Number :  202210268357BF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210268357BF', 'Akangbe Faheedat Temitope', 'F', 'KWARA', 189, 'Economics', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IFELODUN', '08083062840']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6436
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211145798AF : index : 6437
# ===================================================
# fetching content
# Surname :  Raheem
# Fist Name :  Jamiu
# Other Name :  Olamilekan
# Telephone :  07042038987
# Registion Number :  202211145798AF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211145798AF', 'Raheem Jamiu Olamilekan', 'M', 'KWARA', 189, 'Computer Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-EAST', '07042038987']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6437
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210909699DA : index : 6438
# ===================================================
# fetching content
# Surname :  Abdulsalam
# Fist Name :  Rofiat
# Other Name :  Omowumi
# Telephone :  08145064376
# Registion Number :  202210909699DA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210909699DA', 'Abdulsalam Rofiat Omowumi', 'F', 'OYO', 189, 'Common Law', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OLUYOLE', '08145064376']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6438
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210802427CA : index : 6439
# ===================================================
# fetching content
# Surname :  Akande
# Fist Name :  Toluwalase
# Other Name :  Testimony
# Telephone :  08084758235
# Registion Number :  202210802427CA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210802427CA', 'Akande Toluwalase Testimony', 'F', 'KWARA', 189, 'Civil Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IFELODUN', '08084758235']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6439
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210190961GA : index : 6440
# ===================================================
# fetching content
# Surname :  Fagbemi
# Fist Name :  Jesumbo
# Other Name :  Deborah
# Telephone :  08067962699
# Registion Number :  202210190961GA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210190961GA', 'Fagbemi Jesumbo Deborah', 'F', 'KWARA', 189, 'Microbiology', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'EKITI', '08067962699']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6440
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210465594CF : index : 6441
# ===================================================
# fetching content
# Surname :  Ismailah
# Fist Name :  Abdulquadir
# Other Name :  Omo
# Telephone :  07025962349
# Registion Number :  202210465594CF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210465594CF', 'Ismailah Abdulquadir Omo', 'M', 'EDO', 189, 'Computer Science', nan, 'Not Admitted', 'EDO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ETSAKO-WEST', '07025962349']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6441
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211117760HA : index : 6442
# ===================================================
# fetching content
# Surname :  Olatunji
# Fist Name :  Samad
# Other Name :  Olayiwola
# Telephone :  08129981718
# Registion Number :  202211117760HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211117760HA', 'Olatunji Samad Olayiwola', 'M', 'OSUN', 189, 'Biochemistry', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'EJIGBO', '08129981718']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6442
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211240377CA : index : 6443
# ===================================================
# fetching content
# Surname :  Arogundade
# Fist Name :  Latifat
# Other Name :  Ayinke
# Telephone :  08110738678
# Registion Number :  202211240377CA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211240377CA', 'Arogundade Latifat Ayinke', 'F', 'KWARA', 189, 'English Language', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ASA', '08110738678']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6443
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210404090DA : index : 6444
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   6444
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210829314BA : index : 6445
# ===================================================
# fetching content
# Surname :  Arokoola
# Fist Name :  Samuel
# Other Name :  Olamilekan
# Telephone :  08026762212
# Registion Number :  202210829314BA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210829314BA', 'Arokoola Samuel Olamilekan', 'M', 'KWARA', 189, 'Mechanical Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IREPODUN', '08026762212']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6445
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211698486CA : index : 6446
# ===================================================
# fetching content
# Surname :  Ishola
# Fist Name :  Nofisat
# Other Name :  Omoshalewa
# Telephone :  09161439035
# Registion Number :  202211698486CA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211698486CA', 'Ishola Nofisat Omoshalewa', 'F', 'KWARA', 189, 'Food Science & Technology', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IFELODUN', '09161439035']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6446
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211501847GA : index : 6447
# ===================================================
# fetching content
# Surname :  Johnson
# Fist Name :  Ayomide
# Other Name :  Peter
# Telephone :  07060511614
# Registion Number :  202211501847GA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211501847GA', 'Johnson Ayomide Peter', 'M', 'KWARA', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYUN', '07060511614']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6447
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211533085FA : index : 6448
# ===================================================
# fetching content
# Surname :  Yusuf
# Fist Name :  Abdulrasheed
# Other Name :  Omotosho
# Telephone :  08024765547
# Registion Number :  202211533085FA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211533085FA', 'Yusuf Abdulrasheed Omotosho', 'M', 'KWARA', 189, 'Public Health Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-SOUTH', '08024765547']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6448
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211681395HA : index : 6449
# ===================================================
# fetching content
# Surname :  Ojo
# Fist Name :  Selim
# Other Name :  Gbolahan
# Telephone :  09037090563
# Registion Number :  202211681395HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211681395HA', 'Ojo Selim Gbolahan', 'M', 'OYO', 189, 'Accounting', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IBADAN SOUTH EAST', '09037090563']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6449
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211185168JA : index : 6450
# ===================================================
# fetching content
# Surname :  Oyeleke
# Fist Name :  Kadijat
# Other Name :  Oyebisi
# Telephone :  08084029220
# Registion Number :  202211185168JA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211185168JA', 'Oyeleke Kadijat Oyebisi', 'F', 'OYO', 189, 'Mass Communication', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'AFIJIO', '08084029220']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6450
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211127699GA : index : 6451
# ===================================================
# fetching content
# Surname :  Alakanse
# Fist Name :  Boluwatife
# Other Name :  Abeke
# Telephone :  09011362961
# Registion Number :  202211127699GA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211127699GA', 'Alakanse Boluwatife Abeke', 'F', 'OYO', 189, 'Accounting', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ISEYIN', '09011362961']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6451
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211591428IA : index : 6452
# ===================================================
# fetching content
# Surname :  Bamidele
# Fist Name :  Peace
# Other Name :  Jumoke
# Telephone :  09152272607
# Registion Number :  202211591428IA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211591428IA', 'Bamidele Peace Jumoke', 'F', 'KWARA', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ISIN', '09152272607']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6452
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210718263IF : index : 6453
# ===================================================
# fetching content
# Surname :  Adebayo
# Fist Name :  Oluwatobiloba
# Other Name :  Omotayo
# Telephone :  08023180977
# Registion Number :  202210718263IF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210718263IF', 'Adebayo Oluwatobiloba Omotayo', 'M', 'OGUN', 189, 'Common Law', nan, 'Not Admitted', 'OGUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IJEBU-NORTH', '08023180977']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6453
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210706125HA : index : 6454
# ===================================================
# fetching content
# Surname :  Atoyebi
# Fist Name :  Fareedat
# Other Name :  Morolake
# Telephone :  07014024800
# Registion Number :  202210706125HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210706125HA', 'Atoyebi Fareedat Morolake', 'F', 'KWARA', 189, 'Chemistry', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IFELODUN', '07014024800']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6454
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210774225FA : index : 6455
# ===================================================
# fetching content
# Surname :  Quadri
# Fist Name :  Abdullah
# Other Name :  Akolade
# Telephone :  07037897329
# Registion Number :  202210774225FA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210774225FA', 'Quadri Abdullah Akolade', 'M', 'OYO', 189, 'Public Health Science', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYO-EAST', '07037897329']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6455
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210542252GA : index : 6456
# ===================================================
# fetching content
# Surname :  Saliu
# Fist Name :  Saidat
# Other Name :
# Telephone :  08146182533
# Registion Number :  202210542252GA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210542252GA', 'Saliu Saidat', 'F', 'KWARA', 189, 'Biochemistry', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-EAST', '08146182533']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6456
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210381544JA : index : 6457
# ===================================================
# fetching content
# Surname :  Onweunwuzor
# Fist Name :  Samson
# Other Name :  Onyedikachukwu
# Telephone :  09039103998
# Registion Number :  202210381544JA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210381544JA', 'Onweunwuzor Samson Onyedikachukwu', 'M', 'DELTA', 189, 'Microbiology', nan, 'Not Admitted', 'DELTA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OSHIMILI-NORTH', '09039103998']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6457
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210518823HA : index : 6458
# ===================================================
# fetching content
# Surname :  Adediran
# Fist Name :  Fakharudeen
# Other Name :  Adebowale
# Telephone :  09074407749
# Registion Number :  202210518823HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210518823HA', 'Adediran Fakharudeen Adebowale', 'M', 'OYO', 189, 'Public Administration', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IREPO', '09074407749']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6458
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210400990EF : index : 6459
# ===================================================
# fetching content
# Surname :  Atoyebi
# Fist Name :  Favour
# Other Name :  Inioluwa
# Telephone :  08125116446
# Registion Number :  202210400990EF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210400990EF', 'Atoyebi Favour Inioluwa', 'F', 'KWARA', 189, 'Mass Communication', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYUN', '08125116446']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6459
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210976124CF : index : 6460
# ===================================================
# fetching content
# Surname :  Oyedele
# Fist Name :  Zacchaeus
# Other Name :  Timileyin
# Telephone :  07087856620
# Registion Number :  202210976124CF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210976124CF', 'Oyedele Zacchaeus Timileyin', 'M', 'OSUN', 189, 'Public Health Science', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OSOGBO', '07087856620']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6460
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211347174DA : index : 6461
# ===================================================
# fetching content
# Surname :  Asiwaju
# Fist Name :  Rodiat
# Other Name :  Olamide
# Telephone :  09162139306
# Registion Number :  202211347174DA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211347174DA', 'Asiwaju Rodiat Olamide', 'F', 'KWARA', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-EAST', '09162139306']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6461
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210661245IA : index : 6462
# ===================================================
# fetching content
# Surname :  Saliu
# Fist Name :  Abdullahi
# Other Name :  Oluwapelumi
# Telephone :  08052311526
# Registion Number :  202210661245IA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210661245IA', 'Saliu Abdullahi Oluwapelumi', 'M', 'KWARA', 189, 'Electrical /Electronics Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'EKITI', '08052311526']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6462
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210138158HA : index : 6463
# ===================================================
# fetching content
# Surname :  Abdulganiyu
# Fist Name :  Zainab
# Other Name :  Omoyeni
# Telephone :  08161750199
# Registion Number :  202210138158HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210138158HA', 'Abdulganiyu Zainab Omoyeni', 'F', 'OSUN', 189, 'Public Health Science', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OSOGBO', '08161750199']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6463
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210486032FF : index : 6464
# ===================================================
# fetching content
# Surname :  Mustapha
# Fist Name :  Oyinkansola
# Other Name :  Mariam
# Telephone :  09078452521
# Registion Number :  202210486032FF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210486032FF', 'Mustapha Oyinkansola Mariam', 'F', 'OYO', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ATIBA', '09078452521']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6464
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211007232JF : index : 6465
# ===================================================
# fetching content
# Surname :  Nurudeen
# Fist Name :  Taoheed
# Other Name :
# Telephone :  09038598115
# Registion Number :  202211007232JF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211007232JF', 'Nurudeen Taoheed', 'M', 'KWARA', 189, 'Mechanical Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ASA', '09038598115']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6465
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211393147GF : index : 6466
# ===================================================
# fetching content
# Surname :  Obafemi
# Fist Name :  Feranmi
# Other Name :  Ruth
# Telephone :  07088266796
# Registion Number :  202211393147GF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211393147GF', 'Obafemi Feranmi Ruth', 'F', 'KOGI', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'KOGI', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'KABBA/BUNU', '07088266796']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6466
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210909341BF : index : 6467
# ===================================================
# fetching content
# Surname :  Badmus
# Fist Name :  Hikimat
# Other Name :  Idera
# Telephone :  09024294798
# Registion Number :  202210909341BF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210909341BF', 'Badmus Hikimat Idera', 'F', 'OYO', 189, 'Business Administration', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYO-EAST', '09024294798']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6467
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211688187CF : index : 6468
# ===================================================
# fetching content
# Surname :  Fakowajo
# Fist Name :  Happiness
# Other Name :  Oluwatunmise
# Telephone :  07053313031
# Registion Number :  202211688187CF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211688187CF', 'Fakowajo Happiness Oluwatunmise', 'F', 'OSUN', 189, 'Mass Communication', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ATAKUMOSA', '07053313031']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6468
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210086202CF : index : 6469
# ===================================================
# fetching content
# Surname :  Odelabi
# Fist Name :  Eunice
# Other Name :  Taiwo
# Telephone :  09125313209
# Registion Number :  202210086202CF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210086202CF', 'Odelabi Eunice Taiwo', 'F', 'OYO', 189, 'Mass Communication', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OGBOMOSHO SOUTH', '09125313209']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6469
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210326550DF : index : 6470
# ===================================================
# fetching content
# Surname :  Alao
# Fist Name :  Zainab
# Other Name :  Opeyemi
# Telephone :  08127994649
# Registion Number :  202210326550DF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210326550DF', 'Alao Zainab Opeyemi', 'F', 'KWARA', 189, 'Political Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-WEST', '08127994649']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6470
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210449251EA : index : 6471
# ===================================================
# fetching content
# Surname :  Amoo
# Fist Name :  Yusuf
# Other Name :  Olakunle
# Telephone :  08082939743
# Registion Number :  202210449251EA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210449251EA', 'Amoo Yusuf Olakunle', 'M', 'OYO', 189, 'Computer Engineering', nan, 'Not Admitted', 'OYO', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OYO-WEST', '08082939743']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6471
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210903906CA : index : 6472
# ===================================================
# fetching content
# Surname :  Afolarin
# Fist Name :  Michael
# Other Name :  Mercy
# Telephone :  08134249187
# Registion Number :  202210903906CA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210903906CA', 'Afolarin Michael Mercy', 'M', 'EKITI', 189, 'Electrical /Electronics Engineering', nan, 'Not Admitted', 'EKITI', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IKERE', '08134249187']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6472
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210043816BA : index : 6473
# ===================================================
# fetching content
# Surname :  Williams
# Fist Name :  Ambrose
# Other Name :  Joseph
# Telephone :  07044045838
# Registion Number :  202210043816BA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210043816BA', 'Williams Ambrose Joseph', 'M', 'BENUE', 189, 'Political Science', nan, 'Not Admitted', 'BENUE', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'GUMA', '07044045838']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6473
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210855169DA : index : 6474
# ===================================================
# fetching content
# Surname :  Jaiyeola
# Fist Name :  Muktair
# Other Name :  Abidemi
# Telephone :  08113344830
# Registion Number :  202210855169DA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210855169DA', 'Jaiyeola Muktair Abidemi', 'M', 'OGUN', 189, 'Political Science', nan, 'Not Admitted', 'OGUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'IKENNE', '08113344830']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6474
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211728936FF : index : 6475
# ===================================================
# fetching content
# Surname :  Abubakar
# Fist Name :  Ibrahim
# Other Name :  Ayomide
# Telephone :  07058508936
# Registion Number :  202211728936FF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211728936FF', 'Abubakar Ibrahim Ayomide', 'M', 'KWARA', 189, 'Banking & Finance', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-WEST', '07058508936']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6475
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210072152HA : index : 6476
# ===================================================
# fetching content
# Surname :  Murtala
# Fist Name :  Ameenah
# Other Name :  Ajoke
# Telephone :  09160827864
# Registion Number :  202210072152HA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210072152HA', 'Murtala Ameenah Ajoke', 'F', 'KWARA', 189, 'Public Health Science', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-SOUTH', '09160827864']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6476
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210175676BA : index : 6477
# ===================================================
# fetching content
# Surname :  Sanusi
# Fist Name :  Abdul-Rahman
# Other Name :  Olayinka
# Telephone :  07085513640
# Registion Number :  202210175676BA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210175676BA', 'Sanusi Abdul-Rahman Olayinka', 'M', 'LAGOS', 189, 'Medical Laboratory Science', nan, 'Not Admitted', 'LAGOS', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'LAGOS-ISLAND', '07085513640']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6477
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202210513344BA : index : 6478
# ===================================================
# fetching content
# Surname :  Abdullahi
# Fist Name :  Muizat
# Other Name :  Opeyemi
# Telephone :  07065375889
# Registion Number :  202210513344BA
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202210513344BA', 'Abdullahi Muizat Opeyemi', 'F', 'KWARA', 189, 'Common Law', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-SOUTH', '07065375889']
# Row addes successfully.....
# ...
#                      STUDENT CONFIRMED...
# ['202211732740DF', 'Apaokagi Saadudeen Babatunde', 'M', 'KWARA', 189, 'Mechanical Engineering', nan, 'Not Admitted', 'KWARA', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'ILORIN-WEST', '08060242377']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6635
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211345092IF : index : 6636
# ===================================================
# fetching content
# Surname :  Ganiu
# Fist Name :  Zainab
# Other Name :  Olanike
# Telephone :  09064174582
# Registion Number :  202211345092IF
# VALID :  True
#                      STUDENT CONFIRMED...
# ['202211345092IF', 'Ganiu Zainab Olanike', 'F', 'OSUN', 189, 'Banking & Finance', nan, 'Not Admitted', 'OSUN', 'KWARA STATE UNIVERSITY, MALETE, ILORIN, KWARA STATE', 'OLORUNDA', '09064174582']
# Row addes successfully.....
# ==================================================
#               END MINING     No.   6636
# ==================================================
#
# ========== SOURCE FILE SIZE IS ==>  15355
# ===================================================
#    START MINING   FOR :  202211428679FF : index : 6637
# ===================================================
# fetching content
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In [7], line 57
#      54 print(f'   START MINING   FOR :  {reg} : index : {index}  ')
#      55 print('===================================================')
# ---> 57 data , lenght = fetch_info(reg)
#      58 if lenght != 0 :
#      59
#      60     # printing data for confirmation
#      61     try:
#
# Cell In [7], line 34, in fetch_info(reg_number)
#      32 print('fetching content')
#      33 url = f'https://efacility.jamb.gov.ng/TempFiles/Main_Examination_Slip_{reg_number}.htm'
# ---> 34 page = requests.get(url)
#      35 soup = BeautifulSoup(page.text, 'html.parser')
#      36 data = soup.find_all('label')
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))

# %%
# 4331
