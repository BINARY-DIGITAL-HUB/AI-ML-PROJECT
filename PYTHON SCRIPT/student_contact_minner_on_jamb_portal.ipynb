# %% [markdown]
# #  SIMPLE PYTHON DATA MINING SCRIPT FOR JAMB STUDENT

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

# %%
driver= webdriver.Chrome()

def fetch_info(reg_number):
    driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip') 
    reg = driver.find_element('id' , "txtRegNumber")
    reg.send_keys(reg_number)

    # submitting form
    # reg.submit()
    sb = driver.find_element('id' , "lnkSearch")

    sb.click()
    # driver.refresh()
    # print('WEB PAGE ', driver.current_url)


    # getting data from html document
    print('fetching content')
    url = f'https://efacility.jamb.gov.ng/TempFiles/Main_Examination_Slip_{reg_number}.htm'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    data = soup.find_all('label')

    return data , len(data)

# %%
fetch_info('value')
# Out:
# Complete :  1
# fetching content
# ([], 0)

# %%
import pandas as pd 

data = pd.read_csv('abuja.csv')
data
# Out:
#               RG_NUM              RG_CANDNAME RG_SEX STATE_NAME  RG_AGGREGATE  \
# 0     202210013646JF     Biyang Gadani Loveth      F     KADUNA           170
# 1     202210016064HA     Agee Innocent Iormba      M      BENUE           170
# 2     202210026724GF  Nwachukwu Charles Emeka      M      ENUGU           170
# 3     202210035921GA         Momoh Abdulwadud      M        EDO           170
# 4     202210036488HF   Terna Emmanuel Sughnen      M      BENUE           170
# ...              ...                      ...    ...        ...           ...
# 8087  202211480181JA      Tanimu Yusuf Salaha      F   NASARAWA           102
# 8088  202210192087DF    Mayowa Olayinka Mercy      F      EKITI           100
# 8089  202210374764HF          Abubakar Rilwan      M     KADUNA           100
# 8090  202211243210BA              Danjuma Ele      F       KOGI           100
# 8091  202211284846HA       Umar Sabeel Fa'Iza      F     KADUNA           100
#
#                       CO_NAME  PUTMESCORE AdmissionStatus State_Name1  \
# 0          Medicine & Surgery         NaN    Not Admitted      KADUNA
# 1            Computer Science         NaN    Not Admitted       BENUE
# 2            Computer Science         NaN    Not Admitted       ENUGU
# 3           Civil Engineering         NaN    Not Admitted         EDO
# 4       Public Administration         NaN    Not Admitted       BENUE
# ...                       ...         ...             ...         ...
# 8087       Medicine & Surgery         NaN    Not Admitted    NASARAWA
# 8088               Accounting         NaN    Not Admitted       EKITI
# 8089  Business Administration         NaN    Not Admitted      KADUNA
# 8090    Public Administration         NaN    Not Admitted        KOGI
# 8091         Computer Science         NaN    Not Admitted      KADUNA
#
#                              Instname     LGA_Name
# 0     UNIVERSITY OF ABUJA, ABUJA, FCT  ZANGO-KATAF
# 1     UNIVERSITY OF ABUJA, ABUJA, FCT         UKUM
# 2     UNIVERSITY OF ABUJA, ABUJA, FCT   NKANU-EAST
# 3     UNIVERSITY OF ABUJA, ABUJA, FCT  ETSAKO-WEST
# 4     UNIVERSITY OF ABUJA, ABUJA, FCT       BURUKU
# ...                               ...          ...
# 8087  UNIVERSITY OF ABUJA, ABUJA, FCT         TOTO
# 8088  UNIVERSITY OF ABUJA, ABUJA, FCT    ADO-EKITI
# 8089  UNIVERSITY OF ABUJA, ABUJA, FCT        IGABI
# 8090  UNIVERSITY OF ABUJA, ABUJA, FCT       DEKINA
# 8091  UNIVERSITY OF ABUJA, ABUJA, FCT        IGABI
#
# [8092 rows x 11 columns]

# %%
row , col  = data.shape
print('Total data is : ', row)
# Out:
# Total data is :  8092

# %%
 data.columns
# Out:
# Index(['RG_NUM', 'RG_CANDNAME', 'RG_SEX', 'STATE_NAME', 'RG_AGGREGATE',
#        'CO_NAME', 'PUTMESCORE', 'AdmissionStatus', 'State_Name1', 'Instname',
#        'LGA_Name'],
#       dtype='object')

# %%
candidate_name = data["RG_CANDNAME"].values
candidate_reg = data["RG_NUM"].values
candidate_name
# Out:
# array(['Ifatanmi Kikelomo Oluwafunke', 'Awotongha Golubo Wisdom',
#        'Ayandare Micheal Segun', 'Ozogoro Arikeade Ifedolapo'],
#       dtype=object)

# %%
names = list(candidate_name)
regs = list(candidate_reg)
regs
# Out:
# ['202211484000JA', '202211363179JA', '202210974254GF', '202210953291JF']

# %% [markdown]
# # validating original data with mined data ....

# %%
# simulating a simple demo instance 
reg = regs[0]
name = names[0]


# helper method to valide content compatibility 
def check_content_matching(o_reg='data_reg' , o_name='d_name' , m_reg='mine_reg' , m_name = 'm_name'): 
#   : o_reg / the import jamb student registration number 
#   : o_name / the import jamb student name 
#   : m_reg / the mined student registration number 
#   : m_name / the mined student name 
    validate = False 
    if (m_reg.upper().strip() == o_reg.upper().strip() and m_name.lower() in o_name.lower().split()):
        validate = True
    else : 
        validate = False
        
    return validate ; 

valid = check_content_matching(reg , name , '202211484000JA', 'KIKeLOMO')

# %%
# creating new dataframe using existing attribute with additional attribute.... 
import pandas as pd
def create_dataframe(dataframe,  add=''):
    attributes = []

    for attr in dataframe.columns: 
        attributes.append(attr)
    if add != '':
        attributes.append(add)

    print(attributes)
    df = pd.DataFrame(columns=attributes)
    return df , attributes
    
df , _ = create_dataframe(data, 'Contact')

df

def add_row(old_table , new_table, m_reg = ''):
    
    if m_reg != '':
        d = old_table[old_table[old_table.columns[0]] == m_reg]
        tem_value = []
        for value in d.values:
            tem_value.append(value)
        tem_value.append(tel)
        
        new_table.iloc(len(new_table)) = tem_value
        new_table.to_csv('generate_record.csv')
        retun new_table
        
        
# add_row(data, df, '202211484000JA')
    
# def append_new_record():
#     pass
# Out:
# ['RG_NUM', 'RG_CANDNAME', 'RG_SEX', 'STATE_NAME', 'RG_AGGREGATE', 'CO_NAME', 'PUTMESCORE', 'AdmissionStatus', 'State_Name1', 'Instname', 'LGA_Name', 'Contact']
# Empty DataFrame
# Columns: [RG_NUM, RG_CANDNAME, RG_SEX, STATE_NAME, RG_AGGREGATE, CO_NAME, PUTMESCORE, AdmissionStatus, State_Name1, Instname, LGA_Name, Contact]
# Index: []

# %%
# regs = ['202211484000JA', '202211363179JA', '202210974254GF']
# regs = ['202211484000JA']

for reg in regs:
    print()
    print('=========================')
    print('       START MINING      ')
    print('=========================')

    data , lenght = fetch_info(reg)
    if lenght != 0 : 
        # printing data for confirmation
        surname = data[1].get_text()
        firstname = data[2].get_text()
        othername = data[4].get_text()
        tel = data[12].get_text()
        reg_number = data[15].get_text()

        print('Surname : ' , surname)
        print('Fist Name : ', firstname)
        print('Other Name : ',  othername)
        print('Telephone : ' , tel)
        print('Registion Number : ' , reg_number)


        print('=========================')
        print('         END MINING      ')
        print('=========================')

# %% [markdown]
# #  COMBINING ALL CODE INTO A SINGLE SCRIPT

# %%
#     =====================================================================================   #
#                                       FIRST SECTION CODE                                    #
#     =====================================================================================   #

# IMPORTING IMPORTANT MODULE..... 
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pandas as pd

# IMPORTING ORIGINAL DATA 
jamb_data = pd.read_csv('abuja.csv')

# GETTING ATTRIBUTE FROM ORIGINAL DATA
candidate_name = jamb_data["RG_CANDNAME"].values
candidate_reg = jamb_data["RG_NUM"].values
names = list(candidate_name)
regs = list(candidate_reg)
# print(names)
# print(regs)

# GENERATING NEW DATAFRAME
gen_df = pd.DataFrame()
    
try:
    gen_df = pd.read_csv('pool/generate_record5.csv', index=False)
except Exception: 
    pass

def create_dataframe(dataframe,  add=''):
    attributes = []

    for attr in dataframe.columns: 
        attributes.append(attr)
    if add != '':
        attributes.append(add)

    df = pd.DataFrame([] , columns=attributes)

    return df , attributes


if gen_df.empty:
    print('original data is empty')
    gen_df , _ = create_dataframe(jamb_data, 'Contact')

else: 
    pass
# Out:
# original data is empty

# %%
#     =====================================================================================   #
#                                HELPER METHOD FOR SECTION TWO                                #
#     =====================================================================================   #




# helper method to valide content compatibility 

def check_content_matching(o_reg='data_reg' , o_name='d_name' , m_reg='mine_reg' , m_name = 'm_name'): 
    
    #   : o_reg / the import jamb student registration number 
    #   : o_name / the import jamb student name 
    #   : m_reg / the mined student registration number 
    #   : m_name / the mined student name 

    validate = False 
    if (m_reg.upper().strip() == o_reg.upper().strip() and m_name.lower() in o_name.lower().split()):
        validate = True
    else : 
        validate = False
    return validate ; 

# helper method to had new row to the new table
def add_row(old_table , new_table, tel='',  m_reg = ''):
    
    if m_reg != '':
        d = old_table[old_table[old_table.columns[0]] == m_reg]
        old_val = d.values
#         print(old_val.flatten())
        temp_value = []
        for value in list(old_val.flatten()):
            temp_value.append(value)

#         print('TEL:' , tel)

        if tel != '':
            temp_value.append(str(tel))
            
            print(temp_value)
            new_table.loc[len(new_table)] = temp_value
            
            new_table.to_csv('pool/generate_record5.csv')

            return new_table
                
# add_row(jamb_data, gen_df , tel, reg_number)

# %%
#     =====================================================================================   #
#                                       SECOND SECTION CODE                                   #
#     =====================================================================================   #

# eporting to json 

#  to json ...
import json as j




# NAVIGATING THE WEB BROWSER USING THE STUDENT REGISTRATION NUMBER

driver= webdriver.Chrome()

def fetch_info(reg_number):
    driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip') 
    reg = driver.find_element('id' , "txtRegNumber")
    reg.send_keys(reg_number)

    # submitting form
    # reg.submit()
    sb = driver.find_element('id' , "lnkSearch")

    sb.click()
    # driver.refresh()
    # print('WEB PAGE ', driver.current_url)


    # getting data from html document
    print('fetching content')
    url = f'https://efacility.jamb.gov.ng/TempFiles/Main_Examination_Slip_{reg_number}.htm'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    data = soup.find_all('label')

    return data , len(data)


#  scraping through web for contact 

for index in range(398 ,  len(regs)):
    reg = regs[index]
    name = names[index]
      
    
#         with  open('reg_cache.json','w') as file:  
#             file.dump({'last_reg':reg ,  'last_name':name , 'index':index})


    print()
    print('===================================================')
    print(f'   START MINING   FOR :  {reg} : index : {index}  ')
    print('===================================================')

    data , lenght = fetch_info(reg)
    if lenght != 0 :
            
        # printing data for confirmation
        try:
            surname = data[1].get_text()
            firstname = data[2].get_text()
            othername = data[4].get_text()
            tel = data[12].get_text()
            reg_number = data[15].get_text()

            print('Surname : ' , surname)
            print('Fist Name : ', firstname)
            print('Other Name : ',  othername)
            print('Telephone : ' , tel)
            print('Registion Number : ' , reg_number)


        

            valid = check_content_matching(reg, name , reg_number, surname)

            if valid :
                print('                     STUDENT CONFIRMED... ')
                add_row(jamb_data, gen_df , tel, reg_number)
                
        except Exception:
            print('error')
                  
    print('==================================================')
    print(f'              END MINING     No.   {index}       ')
    print('==================================================')
        
        
    
            
            

        
print('==================================================')
print(f'               END OF MINING                     ')
print('==================================================')
# Out:
# ===================================================
#    START MINING   FOR :  202210712498DA : index : 398
# ===================================================
# fetching content
# Surname :  Sunday
# Fist Name :  Joseph
# Other Name :
# Telephone :  09013785248
# Registion Number :  202210712498DA
#                      STUDENT CONFIRMED...
# ['202210712498DA', 'Sunday Joseph', 'M', 'BENUE', 169, 'Microbiology', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OGBADIBO', '09013785248']
# ==================================================
#               END MINING     No.   398
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210713712EA : index : 399
# ===================================================
# fetching content
# Surname :  John
# Fist Name :  Emmanuel
# Other Name :  Anyebe
# Telephone :  08068219322
# Registion Number :  202210713712EA
#                      STUDENT CONFIRMED...
# ['202210713712EA', 'John Anyebe Emmanuel', 'M', 'BENUE', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OHIMINI', '08068219322']
# ==================================================
#               END MINING     No.   399
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210715425CF : index : 400
# ===================================================
# fetching content
# Surname :  Adegboyega
# Fist Name :  Victoria
# Other Name :  Oluwatosin
# Telephone :  09067878772
# Registion Number :  202210715425CF
#                      STUDENT CONFIRMED...
# ['202210715425CF', 'Adegboyega Oluwatosin Victoria', 'F', 'OSUN', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'OSUN', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AYEDA-ADE', '09067878772']
# ==================================================
#               END MINING     No.   400
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210715889IA : index : 401
# ===================================================
# fetching content
# Surname :  Abdulazeez
# Fist Name :  Rukayah
# Other Name :
# Telephone :  07081109845
# Registion Number :  202210715889IA
#                      STUDENT CONFIRMED...
# ['202210715889IA', 'Abdulazeez Rukayah', 'F', 'KWARA', 169, 'Computer Science', nan, 'Not Admitted', 'KWARA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OFFA', '07081109845']
# ==================================================
#               END MINING     No.   401
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210724332EF : index : 402
# ===================================================
# fetching content
# Surname :  Deeyah
# Fist Name :  Praise
# Other Name :  Smart
# Telephone :  09042534403
# Registion Number :  202210724332EF
#                      STUDENT CONFIRMED...
# ['202210724332EF', 'Deeyah Smart Praise', 'F', 'RIVERS', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'RIVERS', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'HANA', '09042534403']
# ==================================================
#               END MINING     No.   402
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210726395IF : index : 403
# ===================================================
# fetching content
# Surname :  Abubakar
# Fist Name :  Muhammad Sanni
# Other Name :
# Telephone :  08036060593
# Registion Number :  202210726395IF
#                      STUDENT CONFIRMED...
# ['202210726395IF', 'Abubakar Muhammad Sanni', 'M', 'KOGI', 169, 'Civil Engineering', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KOGI', '08036060593']
# ==================================================
#               END MINING     No.   403
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210739007BA : index : 404
# ===================================================
# fetching content
# Surname :  Lawrence
# Fist Name :  Aloysius
# Other Name :
# Telephone :  08125736406
# Registion Number :  202210739007BA
#                      STUDENT CONFIRMED...
# ['202210739007BA', 'Lawrence Aloysius', 'M', 'KOGI', 169, 'Computer Science', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ANKPA', '08125736406']
# ==================================================
#               END MINING     No.   404
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210742260IF : index : 405
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   405
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210743801HF : index : 406
# ===================================================
# fetching content
# Surname :  Haruna
# Fist Name :  Sudais
# Other Name :  Agyaye
# Telephone :  09047339088
# Registion Number :  202210743801HF
#                      STUDENT CONFIRMED...
# ['202210743801HF', 'Haruna Agyaye Sudais', 'M', 'FCT', 169, 'Civil Engineering', nan, 'Not Admitted', 'FCT', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MUNICIPAL', '09047339088']
# ==================================================
#               END MINING     No.   406
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210751358AF : index : 407
# ===================================================
# fetching content
# Surname :  Orukpe
# Fist Name :  Harmony
# Other Name :  Eseohe
# Telephone :  09037314235
# Registion Number :  202210751358AF
#                      STUDENT CONFIRMED...
# ['202210751358AF', 'Orukpe Eseohe Harmony', 'F', 'EDO', 169, 'Law', nan, 'Not Admitted', 'EDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ESAN-WEST', '09037314235']
# ==================================================
#               END MINING     No.   407
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210756586IF : index : 408
# ===================================================
# fetching content
# Surname :  Tauheed
# Fist Name :  Shuaibu
# Other Name :  Gbedu
# Telephone :  07037495643
# Registion Number :  202210756586IF
#                      STUDENT CONFIRMED...
# ['202210756586IF', 'Tauheed Gbedu Shuaibu', 'M', 'NIGER', 169, 'Guidance & Counselling', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'LAPAI', '07037495643']
# ==================================================
#               END MINING     No.   408
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210765441IA : index : 409
# ===================================================
# fetching content
# Surname :  Suleiman
# Fist Name :  Bilikisu
# Other Name :  Omoyi
# Telephone :  09021308093
# Registion Number :  202210765441IA
#                      STUDENT CONFIRMED...
# ['202210765441IA', 'Suleiman Omoyi Bilikisu', 'F', 'KOGI', 169, 'Business Administration', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OKEHI', '09021308093']
# ==================================================
#               END MINING     No.   409
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210780376HF : index : 410
# ===================================================
# fetching content
# Surname :  Obafemi
# Fist Name :  Favour
# Other Name :  Joy
# Telephone :  08066011353
# Registion Number :  202210780376HF
#                      STUDENT CONFIRMED...
# ['202210780376HF', 'Obafemi Joy Favour', 'F', 'ONDO', 169, 'Microbiology', nan, 'Not Admitted', 'ONDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AKOKO-SOUTH', '08066011353']
# ==================================================
#               END MINING     No.   410
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210782997IA : index : 411
# ===================================================
# fetching content
# Surname :  Atule
# Fist Name :  Eunice
# Other Name :  Aluda
# Telephone :  08143545601
# Registion Number :  202210782997IA
#                      STUDENT CONFIRMED...
# ['202210782997IA', 'Atule Aluda Eunice', 'F', 'KOGI', 169, 'Microbiology', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'IBAJI', '08143545601']
# ==================================================
#               END MINING     No.   411
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210785447IF : index : 412
# ===================================================
# fetching content
# Surname :  Oyebade
# Fist Name :  Victor
# Other Name :  Adedamola
# Telephone :  08083711359
# Registion Number :  202210785447IF
#                      STUDENT CONFIRMED...
# ['202210785447IF', 'Oyebade Adedamola Victor', 'M', 'EKITI', 169, 'Law', nan, 'Not Admitted', 'EKITI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ADO-EKITI', '08083711359']
# ==================================================
#               END MINING     No.   412
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210787608BF : index : 413
# ===================================================
# fetching content
# Surname :  Gabriel
# Fist Name :  Eldad
# Other Name :
# Telephone :  08161659217
# Registion Number :  202210787608BF
#                      STUDENT CONFIRMED...
# ['202210787608BF', 'Gabriel Eldad', 'M', 'KADUNA', 169, 'Law', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'JABA', '08161659217']
# ==================================================
#               END MINING     No.   413
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210794580CA : index : 414
# ===================================================
# fetching content
# Surname :  Rapheal
# Fist Name :  Babatunde
# Other Name :  Oluwatosin
# Telephone :  09160078022
# Registion Number :  202210794580CA
#                      STUDENT CONFIRMED...
# ['202210794580CA', 'Rapheal Oluwatosin Babatunde', 'M', 'KOGI', 169, 'Computer Science', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KABBA/BUNU', '09160078022']
# ==================================================
#               END MINING     No.   414
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210795783IF : index : 415
# ===================================================
# fetching content
# Surname :  Zakari
# Fist Name :  Shamsiya
# Other Name :  Angulu
# Telephone :  09160249955
# Registion Number :  202210795783IF
#                      STUDENT CONFIRMED...
# ['202210795783IF', 'Zakari Angulu Shamsiya', 'F', 'FCT', 169, 'Agriculture', nan, 'Not Admitted', 'FCT', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'GWAGWALADA', '09160249955']
# ==================================================
#               END MINING     No.   415
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210799076FF : index : 416
# ===================================================
# fetching content
# Surname :  Aminu
# Fist Name :  Firdouz
# Other Name :  Nana
# Telephone :  08175602140
# Registion Number :  202210799076FF
#                      STUDENT CONFIRMED...
# ['202210799076FF', 'Aminu Nana Firdouz', 'F', 'KOGI', 169, 'Public Administration', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ANKPA', '08175602140']
# ==================================================
#               END MINING     No.   416
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210807422DA : index : 417
# ===================================================
# fetching content
# Surname :  Suleman
# Fist Name :  Jasmine
# Other Name :  Godiya
# Telephone :  08093733375
# Registion Number :  202210807422DA
#                      STUDENT CONFIRMED...
# ['202210807422DA', 'Suleman Godiya Jasmine', 'F', 'FCT', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'FCT', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KWALI', '08093733375']
# ==================================================
#               END MINING     No.   417
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210830369FF : index : 418
# ===================================================
# fetching content
# Surname :  Matthew
# Fist Name :  Happiness
# Other Name :  Tumininu
# Telephone :  07067229224
# Registion Number :  202210830369FF
#                      STUDENT CONFIRMED...
# ['202210830369FF', 'Matthew Tumininu Happiness', 'F', 'EKITI', 169, 'Veterinary Medicine', nan, 'Not Admitted', 'EKITI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OYE', '07067229224']
# ==================================================
#               END MINING     No.   418
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210842889GA : index : 419
# ===================================================
# fetching content
# Surname :  Jacob
# Fist Name :  Bunmi
# Other Name :
# Telephone :  09071967267
# Registion Number :  202210842889GA
#                      STUDENT CONFIRMED...
# ['202210842889GA', 'Jacob Bunmi', 'F', 'KOGI', 169, 'Educational Management & Planning', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MOPA-MORO-MOPI', '09071967267']
# ==================================================
#               END MINING     No.   419
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210843923CA : index : 420
# ===================================================
# fetching content
# Surname :  Babatunde
# Fist Name :  Oluwatosin
# Other Name :  Praise
# Telephone :  08070729867
# Registion Number :  202210843923CA
#                      STUDENT CONFIRMED...
# ['202210843923CA', 'Babatunde Praise Oluwatosin', 'F', 'OGUN', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'OGUN', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ABEOKUTA-NORTH', '08070729867']
# ==================================================
#               END MINING     No.   420
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210848267FF : index : 421
# ===================================================
# fetching content
# Surname :  Muyideen
# Fist Name :  Suleiman
# Other Name :  Ishola
# Telephone :  09057594265
# Registion Number :  202210848267FF
#                      STUDENT CONFIRMED...
# ['202210848267FF', 'Muyideen Ishola Suleiman', 'M', 'KWARA', 169, 'Business Administration', nan, 'Not Admitted', 'KWARA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MORO', '09057594265']
# ==================================================
#               END MINING     No.   421
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210852301CF : index : 422
# ===================================================
# fetching content
# Surname :  Mohammed
# Fist Name :  Mohammed
# Other Name :
# Telephone :  08135801390
# Registion Number :  202210852301CF
#                      STUDENT CONFIRMED...
# ['202210852301CF', 'Mohammed Mohammed', 'M', 'BORNO', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'BORNO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'BAMA', '08135801390']
# ==================================================
#               END MINING     No.   422
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210852884FF : index : 423
# ===================================================
# fetching content
# Surname :  Stephen
# Fist Name :  Veronica
# Other Name :  Eleojo
# Telephone :  08098207258
# Registion Number :  202210852884FF
#                      STUDENT CONFIRMED...
# ['202210852884FF', 'Stephen Eleojo Veronica', 'F', 'BENUE', 169, 'Sociology', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OGBADIBO', '08098207258']
# ==================================================
#               END MINING     No.   423
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210866309JF : index : 424
# ===================================================
# fetching content
# Surname :  Otubo
# Fist Name :  Chidera
# Other Name :  Emmanuel
# Telephone :  08068540342
# Registion Number :  202210866309JF
#                      STUDENT CONFIRMED...
# ['202210866309JF', 'Otubo Emmanuel Chidera', 'M', 'EBONYI', 169, 'Civil Engineering', nan, 'Not Admitted', 'EBONYI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'EBONYI', '08068540342']
# ==================================================
#               END MINING     No.   424
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210869074EF : index : 425
# ===================================================
# fetching content
# Surname :  Ayomaya
# Fist Name :  Janet
# Other Name :  Olamide
# Telephone :  09069392368
# Registion Number :  202210869074EF
#                      STUDENT CONFIRMED...
# ['202210869074EF', 'Ayomaya Olamide Janet', 'F', 'ONDO', 169, 'Law', nan, 'Not Admitted', 'ONDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AKOKO-NORTH', '09069392368']
# ==================================================
#               END MINING     No.   425
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210871783IF : index : 426
# ===================================================
# fetching content
# Surname :  Adagiri
# Fist Name :  Suleiman
# Other Name :  Enesi
# Telephone :  07069654247
# Registion Number :  202210871783IF
#                      STUDENT CONFIRMED...
# ['202210871783IF', 'Adagiri Enesi Suleiman', 'M', 'KOGI', 169, 'Electrical Engineering', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ADAVI', '07069654247']
# ==================================================
#               END MINING     No.   426
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210872941JA : index : 427
# ===================================================
# fetching content
# Surname :  Dikko
# Fist Name :  Mercy
# Other Name :  Apansubo
# Telephone :  08125177161
# Registion Number :  202210872941JA
#                      STUDENT CONFIRMED...
# ['202210872941JA', 'Dikko Apansubo Mercy', 'F', 'FCT', 169, 'Accounting', nan, 'Not Admitted', 'FCT', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MUNICIPAL', '08125177161']
# ==================================================
#               END MINING     No.   427
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210874935JF : index : 428
# ===================================================
# fetching content
# Surname :  Igbo
# Fist Name :  Charles
# Other Name :  Okwudili
# Telephone :  07031465601
# Registion Number :  202210874935JF
#                      STUDENT CONFIRMED...
# ['202210874935JF', 'Igbo Okwudili Charles', 'M', 'IMO', 169, 'Law', nan, 'Not Admitted', 'IMO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ORU-EAST', '07031465601']
# ==================================================
#               END MINING     No.   428
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210886431JA : index : 429
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   429
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210888734HA : index : 430
# ===================================================
# fetching content
# Surname :  Ameh
# Fist Name :  Gift
# Other Name :  Ochefije
# Telephone :  07037519829
# Registion Number :  202210888734HA
#                      STUDENT CONFIRMED...
# ['202210888734HA', 'Ameh Ochefije Gift', 'F', 'BENUE', 169, 'Microbiology', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OGBADIBO', '07037519829']
# ==================================================
#               END MINING     No.   430
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210917569BA : index : 431
# ===================================================
# fetching content
# Surname :  Nwachukwu
# Fist Name :  Blossom
# Other Name :  Chizaramekpere
# Telephone :  09077799191
# Registion Number :  202210917569BA
#                      STUDENT CONFIRMED...
# ['202210917569BA', 'Nwachukwu Chizaramekpere Blossom', 'F', 'AKWA IBOM', 169, 'Microbiology', nan, 'Not Admitted', 'AKWA IBOM', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ITU', '09077799191']
# ==================================================
#               END MINING     No.   431
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210920629AF : index : 432
# ===================================================
# fetching content
# Surname :  Mohammed
# Fist Name :  Maimuna
# Other Name :  Dokochi
# Telephone :  08051652909
# Registion Number :  202210920629AF
#                      STUDENT CONFIRMED...
# ['202210920629AF', 'Mohammed Dokochi Maimuna', 'F', 'NIGER', 169, 'Microbiology', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'BIDA', '08051652909']
# ==================================================
#               END MINING     No.   432
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210923590CA : index : 433
# ===================================================
# fetching content
# Surname :  Adebayo
# Fist Name :  Oluwasayo
# Other Name :  Oshoneme
# Telephone :  08135816435
# Registion Number :  202210923590CA
#                      STUDENT CONFIRMED...
# ['202210923590CA', 'Adebayo Oshoneme Oluwasayo', 'F', 'OGUN', 169, 'Public Administration', nan, 'Not Admitted', 'OGUN', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'EGBADO-NORTH', '08135816435']
# ==================================================
#               END MINING     No.   433
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210931620FF : index : 434
# ===================================================
# fetching content
# Surname :  Ishaq
# Fist Name :  Abdulmalik
# Other Name :
# Telephone :  08179937528
# Registion Number :  202210931620FF
#                      STUDENT CONFIRMED...
# ['202210931620FF', 'Ishaq Abdulmalik', 'M', 'NIGER', 169, 'Civil Engineering', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'SULEJA', '08179937528']
# ==================================================
#               END MINING     No.   434
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210935393JF : index : 435
# ===================================================
# fetching content
# Surname :  Adegbenro
# Fist Name :  Faruq
# Other Name :  Ayomide
# Telephone :  08123595550
# Registion Number :  202210935393JF
#                      STUDENT CONFIRMED...
# ['202210935393JF', 'Adegbenro Ayomide Faruq', 'M', 'OYO', 169, 'Civil Engineering', nan, 'Not Admitted', 'OYO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ITESIWAJU', '08123595550']
# ==================================================
#               END MINING     No.   435
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210948731JF : index : 436
# ===================================================
# fetching content
# Surname :  Ochete
# Fist Name :  Jeremiah
# Other Name :  Uche
# Telephone :  09054329379
# Registion Number :  202210948731JF
#                      STUDENT CONFIRMED...
# ['202210948731JF', 'Ochete Uche Jeremiah', 'M', 'BENUE', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OBI', '09054329379']
# ==================================================
#               END MINING     No.   436
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210956227EF : index : 437
# ===================================================
# fetching content
# Surname :  Okaba
# Fist Name :  Prayer
# Other Name :  Njong
# Telephone :  08131302964
# Registion Number :  202210956227EF
#                      STUDENT CONFIRMED...
# ['202210956227EF', 'Okaba Njong Prayer', 'F', 'CROSS RIVER', 169, 'Business Administration', nan, 'Not Admitted', 'CROSS RIVER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'BOKI', '08131302964']
# ==================================================
#               END MINING     No.   437
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210970159CA : index : 438
# ===================================================
# fetching content
# Surname :  Shatai
# Fist Name :  Charity
# Other Name :  Dongu
# Telephone :  08114576143
# Registion Number :  202210970159CA
#                      STUDENT CONFIRMED...
# ['202210970159CA', 'Shatai Dongu Charity', 'F', 'PLATEAU', 169, 'Public Administration', nan, 'Not Admitted', 'PLATEAU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MIKANG', '08114576143']
# ==================================================
#               END MINING     No.   438
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210972053FA : index : 439
# ===================================================
# fetching content
# Surname :  Okolo
# Fist Name :  Obinna
# Other Name :  Vincent
# Telephone :  08135328681
# Registion Number :  202210972053FA
#                      STUDENT CONFIRMED...
# ['202210972053FA', 'Okolo Vincent Obinna', 'M', 'ENUGU', 169, 'Sociology', nan, 'Not Admitted', 'ENUGU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AWGU', '08135328681']
# ==================================================
#               END MINING     No.   439
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210973658AF : index : 440
# ===================================================
# fetching content
# Surname :  Charles
# Fist Name :  Elijah
# Other Name :
# Telephone :  08087816252
# Registion Number :  202210973658AF
#                      STUDENT CONFIRMED...
# ['202210973658AF', 'Charles Elijah', 'M', 'ABIA', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'ABIA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'UMUAHIA-NORTH', '08087816252']
# ==================================================
#               END MINING     No.   440
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210974503FF : index : 441
# ===================================================
# fetching content
# Surname :  Musediq
# Fist Name :  Qudus
# Other Name :  Adewale
# Telephone :  08083345211
# Registion Number :  202210974503FF
#                      STUDENT CONFIRMED...
# ['202210974503FF', 'Musediq Adewale Qudus', 'M', 'OYO', 169, 'Agriculture', nan, 'Not Admitted', 'OYO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OYO-WEST', '08083345211']
# ==================================================
#               END MINING     No.   441
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210989970FA : index : 442
# ===================================================
# fetching content
# Surname :  Ataijong
# Fist Name :  Rachael
# Other Name :  Elijah
# Telephone :  09017315166
# Registion Number :  202210989970FA
#                      STUDENT CONFIRMED...
# ['202210989970FA', 'Ataijong Elijah Rachael', 'F', 'RIVERS', 169, 'Law', nan, 'Not Admitted', 'RIVERS', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'NDONI', '09017315166']
# ==================================================
#               END MINING     No.   442
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210993345IF : index : 443
# ===================================================
# fetching content
# Surname :  Joseph
# Fist Name :  Nsikak
# Other Name :  Danison
# Telephone :  08151533107
# Registion Number :  202210993345IF
#                      STUDENT CONFIRMED...
# ['202210993345IF', 'Joseph Danison Nsikak', 'M', 'AKWA IBOM', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'AKWA IBOM', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MKPAT-ENIN', '08151533107']
# ==================================================
#               END MINING     No.   443
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211000841DF : index : 444
# ===================================================
# fetching content
# Surname :  Eneson
# Fist Name :  Confidence
# Other Name :  Chikasiemobi
# Telephone :  09068205890
# Registion Number :  202211000841DF
#                      STUDENT CONFIRMED...
# ['202211000841DF', 'Eneson Chikasiemobi Confidence', 'M', 'ENUGU', 169, 'Law', nan, 'Not Admitted', 'ENUGU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'UDI', '09068205890']
# ==================================================
#               END MINING     No.   444
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211003919DF : index : 445
# ===================================================
# fetching content
# Surname :  John
# Fist Name :  Stephen
# Other Name :  Ime
# Telephone :  08082728636
# Registion Number :  202211003919DF
#                      STUDENT CONFIRMED...
# ['202211003919DF', 'John Ime Stephen', 'M', 'IMO', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'IMO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ABOH-MBAISE', '08082728636']
# ==================================================
#               END MINING     No.   445
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211006572HA : index : 446
# ===================================================
# fetching content
# Surname :  Yahaya
# Fist Name :  Hafsat
# Other Name :  Onono
# Telephone :  09060793351
# Registion Number :  202211006572HA
#                      STUDENT CONFIRMED...
# ['202211006572HA', 'Yahaya Onono Hafsat', 'F', 'KOGI', 169, 'Microbiology', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OKEHI', '09060793351']
# ==================================================
#               END MINING     No.   446
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211015988BF : index : 447
# ===================================================
# fetching content
# Surname :  Ajah
# Fist Name :  Chidiebere
# Other Name :  Juliana
# Telephone :  07065918491
# Registion Number :  202211015988BF
#                      STUDENT CONFIRMED...
# ['202211015988BF', 'Ajah Juliana Chidiebere', 'F', 'EBONYI', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'EBONYI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OHAOZARA', '07065918491']
# ==================================================
#               END MINING     No.   447
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211028715DA : index : 448
# ===================================================
# fetching content
# Surname :  Moore-Okoro
# Fist Name :  Chioma
# Other Name :  Precious
# Telephone :  09161736027
# Registion Number :  202211028715DA
#                      STUDENT CONFIRMED...
# ['202211028715DA', 'Moore-Okoro Precious Chioma', 'F', 'IMO', 169, 'Economics', nan, 'Not Admitted', 'IMO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'NJABA', '09161736027']
# ==================================================
#               END MINING     No.   448
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211029344CA : index : 449
# ===================================================
# fetching content
# Surname :  Bitrus
# Fist Name :  Zere
# Other Name :  Chayi
# Telephone :  08162045531
# Registion Number :  202211029344CA
#                      STUDENT CONFIRMED...
# ['202211029344CA', 'Bitrus Chayi Zere', 'F', 'PLATEAU', 169, 'Law', nan, 'Not Admitted', 'PLATEAU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'JOS-SOUTH', '08162045531']
# ==================================================
#               END MINING     No.   449
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211044819HA : index : 450
# ===================================================
# fetching content
# Surname :  Yakubu
# Fist Name :  Nafisat
# Other Name :
# Telephone :  07060508722
# Registion Number :  202211044819HA
#                      STUDENT CONFIRMED...
# ['202211044819HA', 'Yakubu Nafisat', 'F', 'NIGER', 169, 'Educational Management & Planning', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'SULEJA', '07060508722']
# ==================================================
#               END MINING     No.   450
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211047496IA : index : 451
# ===================================================
# fetching content
# Surname :  Umeugo
# Fist Name :  Odinaka
# Other Name :  Justin
# Telephone :  09074002311
# Registion Number :  202211047496IA
#                      STUDENT CONFIRMED...
# ['202211047496IA', 'Umeugo Justin Odinaka', 'M', 'IMO', 169, 'Computer Science', nan, 'Not Admitted', 'IMO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'IDEATO-NORTH', '09074002311']
# ==================================================
#               END MINING     No.   451
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211051386BA : index : 452
# ===================================================
# fetching content
# Surname :  Christopher
# Fist Name :  Dorathy
# Other Name :
# Telephone :  07038842555
# Registion Number :  202211051386BA
#                      STUDENT CONFIRMED...
# ['202211051386BA', 'Christopher Dorathy', 'F', 'KADUNA', 169, 'Education & English Language', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'SANGA', '07038842555']
# ==================================================
#               END MINING     No.   452
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211057775IA : index : 453
# ===================================================
# fetching content
# Surname :  Joseph
# Fist Name :  Precious
# Other Name :  Gundo
# Telephone :  07043958954
# Registion Number :  202211057775IA
#                      STUDENT CONFIRMED...
# ['202211057775IA', 'Joseph Gundo Precious', 'F', 'BENUE', 169, 'Public Administration', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OKPOKWU', '07043958954']
# ==================================================
#               END MINING     No.   453
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211059224FF : index : 454
# ===================================================
# fetching content
# Surname :  Johnson
# Fist Name :  Victor
# Other Name :  Onome
# Telephone :  09021124759
# Registion Number :  202211059224FF
#                      STUDENT CONFIRMED...
# ['202211059224FF', 'Johnson Onome Victor', 'M', 'DELTA', 169, 'Mechanical Engineering', nan, 'Not Admitted', 'DELTA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'WARRI-CENTRAL', '09021124759']
# ==================================================
#               END MINING     No.   454
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211061895JF : index : 455
# ===================================================
# fetching content
# Surname :  Adedoyin
# Fist Name :  Ruth
# Other Name :  Oluwatosin
# Telephone :  08027438458
# Registion Number :  202211061895JF
#                      STUDENT CONFIRMED...
# ['202211061895JF', 'Adedoyin Oluwatosin Ruth', 'F', 'ONDO', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'ONDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AKOKO-NORTH-WEST', '08027438458']
# ==================================================
#               END MINING     No.   455
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211065373JA : index : 456
# ===================================================
# fetching content
# Surname :  Ojo
# Fist Name :  Joy
# Other Name :  Oseiza
# Telephone :  09035611357
# Registion Number :  202211065373JA
#                      STUDENT CONFIRMED...
# ['202211065373JA', 'Ojo Oseiza Joy', 'F', 'EDO', 169, 'Law', nan, 'Not Admitted', 'EDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AKOKO-EDO', '09035611357']
# ==================================================
#               END MINING     No.   456
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211066496IA : index : 457
# ===================================================
# fetching content
# Surname :  Anthony
# Fist Name :  Wisdom
# Other Name :  Ohinoyi
# Telephone :  08085619403
# Registion Number :  202211066496IA
#                      STUDENT CONFIRMED...
# ['202211066496IA', 'Anthony Ohinoyi Wisdom', 'M', 'KOGI', 169, 'Computer Science', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OKEHI', '08085619403']
# ==================================================
#               END MINING     No.   457
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211067079BF : index : 458
# ===================================================
# fetching content
# Surname :  Enenwaeneh
# Fist Name :  Chukwuka
# Other Name :  Franklin
# Telephone :  08103649362
# Registion Number :  202211067079BF
#                      STUDENT CONFIRMED...
# ['202211067079BF', 'Enenwaeneh Franklin Chukwuka', 'M', 'ENUGU', 169, 'Accounting', nan, 'Not Admitted', 'ENUGU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'UDI', '08103649362']
# ==================================================
#               END MINING     No.   458
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211097365BF : index : 459
# ===================================================
# fetching content
# Surname :  Akpeese
# Fist Name :  Faith
# Other Name :  Seer
# Telephone :  09026191013
# Registion Number :  202211097365BF
#                      STUDENT CONFIRMED...
# ['202211097365BF', 'Akpeese Seer Faith', 'F', 'BENUE', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KATSINA-ALA', '09026191013']
# ==================================================
#               END MINING     No.   459
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211098469AF : index : 460
# ===================================================
# fetching content
# Surname :  Ugochukwu
# Fist Name :  Uchenna
# Other Name :  Godswill
# Telephone :  08123879601
# Registion Number :  202211098469AF
#                      STUDENT CONFIRMED...
# ['202211098469AF', 'Ugochukwu Godswill Uchenna', 'M', 'ABIA', 169, 'Accounting', nan, 'Not Admitted', 'ABIA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'UMUAHIA-SOUTH', '08123879601']
# ==================================================
#               END MINING     No.   460
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211098496GA : index : 461
# ===================================================
# fetching content
# Surname :  Ajibola
# Fist Name :  Precious
# Other Name :  Mayowa
# Telephone :  09160609191
# Registion Number :  202211098496GA
#                      STUDENT CONFIRMED...
# ['202211098496GA', 'Ajibola Mayowa Precious', 'F', 'EKITI', 169, 'Computer Science', nan, 'Not Admitted', 'EKITI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'IREPODUN/IFELODUN', '09160609191']
# ==================================================
#               END MINING     No.   461
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211106117FA : index : 462
# ===================================================
# fetching content
# Surname :  Oko
# Fist Name :  Blessing
# Other Name :  Igimi
# Telephone :  07068262436
# Registion Number :  202211106117FA
#                      STUDENT CONFIRMED...
# ['202211106117FA', 'Oko Igimi Blessing', 'F', 'CROSS RIVER', 169, 'Accounting', nan, 'Not Admitted', 'CROSS RIVER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'YALA', '07068262436']
# ==================================================
#               END MINING     No.   462
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211110521HA : index : 463
# ===================================================
# fetching content
# Surname :  Ismail
# Fist Name :  Abubakar
# Other Name :  Oyarebu
# Telephone :  08074767151
# Registion Number :  202211110521HA
#                      STUDENT CONFIRMED...
# ['202211110521HA', 'Ismail Oyarebu Abubakar', 'M', 'EDO', 169, 'Public Administration', nan, 'Not Admitted', 'EDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ETSAKO-WEST', '08074767151']
# ==================================================
#               END MINING     No.   463
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211131719AF : index : 464
# ===================================================
# fetching content
# Surname :  Nwali
# Fist Name :  Chimamkpa
# Other Name :  Paul
# Telephone :  09011316605
# Registion Number :  202211131719AF
#                      STUDENT CONFIRMED...
# ['202211131719AF', 'Nwali Paul Chimamkpa', 'M', 'EBONYI', 169, 'Political Science & International Relations', nan, 'Not Admitted', 'EBONYI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ONICHA', '09011316605']
# ==================================================
#               END MINING     No.   464
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211132219HA : index : 465
# ===================================================
# fetching content
# Surname :  Abdulrahman
# Fist Name :  Saleh
# Other Name :
# Telephone :  08165264159
# Registion Number :  202211132219HA
#                      STUDENT CONFIRMED...
# ['202211132219HA', 'Abdulrahman Saleh', 'M', 'NIGER', 169, 'Computer Science', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'SULEJA', '08165264159']
# ==================================================
#               END MINING     No.   465
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211142827EA : index : 466
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   466
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211150229IA : index : 467
# ===================================================
# fetching content
# Surname :  Brian
# Fist Name :  Hopewell
# Other Name :  Ata
# Telephone :  09071056217
# Registion Number :  202211150229IA
#                      STUDENT CONFIRMED...
# ['202211150229IA', 'Brian Ata Hopewell', 'M', 'CROSS RIVER', 169, 'Sociology', nan, 'Not Admitted', 'CROSS RIVER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'BEKWARA', '09071056217']
# ==================================================
#               END MINING     No.   467
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211151114CF : index : 468
# ===================================================
# fetching content
# Surname :  Ikpa
# Fist Name :  Simon
# Other Name :
# Telephone :  07065254476
# Registion Number :  202211151114CF
#                      STUDENT CONFIRMED...
# ['202211151114CF', 'Ikpa Simon', 'M', 'BENUE', 169, 'Sociology', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'GWER-EAST', '07065254476']
# ==================================================
#               END MINING     No.   468
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211155385EF : index : 469
# ===================================================
# fetching content
# Surname :  Idris
# Fist Name :  Haruna
# Other Name :  Ojo
# Telephone :  08143347860
# Registion Number :  202211155385EF
#                      STUDENT CONFIRMED...
# ['202211155385EF', 'Idris Ojo Haruna', 'M', 'KOGI', 169, 'Public Administration', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OKEHI', '08143347860']
# ==================================================
#               END MINING     No.   469
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211161162EA : index : 470
# ===================================================
# fetching content
# Surname :  Moses
# Fist Name :  Joshua
# Other Name :  Timilehin
# Telephone :  08187312291
# Registion Number :  202211161162EA
#                      STUDENT CONFIRMED...
# ['202211161162EA', 'Moses Timilehin Joshua', 'M', 'ONDO', 169, 'Mechanical Engineering', nan, 'Not Admitted', 'ONDO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'AKURE', '08187312291']
# ==================================================
#               END MINING     No.   470
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202211163451JA : index : 471
# ===================================================
# fetching content
# Surname :  Tyona
# Fist Name :  Shadrach
# Other Name :  Igbadoo
# Telephone :  09162030029
# Registion Number :  202211163451JA
#                      STUDENT CONFIRMED...
# ['202211163451JA', 'Tyona Igbadoo Shadrach', 'M', 'BENUE', 169, 'Medicine & Surgery', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MAKURDI', '09162030029']
# ...
# ==================================================
#               END MINING     No.   1125
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210009377GF : index : 1126
# ===================================================
# fetching content
# Surname :  Adamu
# Fist Name :  Khadijat
# Other Name :  Asbangu
# Telephone :  07081418636
# Registion Number :  202210009377GF
#                      STUDENT CONFIRMED...
# ['202210009377GF', 'Adamu Asbangu Khadijat', 'F', 'NASARAWA', 166, 'Microbiology', nan, 'Not Admitted', 'NASARAWA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'NASSARAWA', '07081418636']
# ==================================================
#               END MINING     No.   1126
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210012013JA : index : 1127
# ===================================================
# fetching content
# Surname :  Eluemunor
# Fist Name :  Peculiar
# Other Name :
# Telephone :  07044667388
# Registion Number :  202210012013JA
#                      STUDENT CONFIRMED...
# ['202210012013JA', 'Eluemunor Peculiar', 'F', 'DELTA', 166, 'Medicine & Surgery', nan, 'Not Admitted', 'DELTA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ANIOCHA SOUTH', '07044667388']
# ==================================================
#               END MINING     No.   1127
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210025279HA : index : 1128
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   1128
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210027352GA : index : 1129
# ===================================================
# fetching content
# Surname :  Patrick
# Fist Name :  Jeremiah
# Other Name :  Audu
# Telephone :  09039982187
# Registion Number :  202210027352GA
#                      STUDENT CONFIRMED...
# ['202210027352GA', 'Patrick Audu Jeremiah', 'M', 'NIGER', 166, 'Electrical Engineering', nan, 'Not Admitted', 'NIGER', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'PAIKORO', '09039982187']
# ==================================================
#               END MINING     No.   1129
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210027861IA : index : 1130
# ===================================================
# fetching content
# Surname :  Muhammad
# Fist Name :  Sumayya
# Other Name :  Murtada
# Telephone :  08026915545
# Registion Number :  202210027861IA
#                      STUDENT CONFIRMED...
# ['202210027861IA', 'Muhammad Murtada Sumayya', 'F', 'KANO', 166, 'Microbiology', nan, 'Not Admitted', 'KANO', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'MADOBI', '08026915545']
# ==================================================
#               END MINING     No.   1130
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210041261FF : index : 1131
# ===================================================
# fetching content
# Surname :  Bako
# Fist Name :  Precious
# Other Name :  Madhi
# Telephone :  08059966307
# Registion Number :  202210041261FF
#                      STUDENT CONFIRMED...
# ['202210041261FF', 'Bako Madhi Precious', 'F', 'KADUNA', 166, 'Medicine & Surgery', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ZANGO-KATAF', '08059966307']
# ==================================================
#               END MINING     No.   1131
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210045289FF : index : 1132
# ===================================================
# fetching content
# Surname :  Hosea
# Fist Name :  Faith
# Other Name :  Uchu
# Telephone :  09020208055
# Registion Number :  202210045289FF
#                      STUDENT CONFIRMED...
# ['202210045289FF', 'Hosea Uchu Faith', 'F', 'PLATEAU', 166, 'Medicine & Surgery', nan, 'Not Admitted', 'PLATEAU', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'BASSA', '09020208055']
# ==================================================
#               END MINING     No.   1132
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210048459HA : index : 1133
# ===================================================
# fetching content
# Surname :  Tanko
# Fist Name :  Moses
# Other Name :  Monday
# Telephone :  07030994269
# Registion Number :  202210048459HA
#                      STUDENT CONFIRMED...
# ['202210048459HA', 'Tanko Monday Moses', 'M', 'KADUNA', 166, 'Political Science & International Relations', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KACHIA', '07030994269']
# ==================================================
#               END MINING     No.   1133
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210049725BA : index : 1134
# ===================================================
# fetching content
# Surname :  Okoye
# Fist Name :  Charles
# Other Name :  Mmesoma
# Telephone :  09132691744
# Registion Number :  202210049725BA
#                      STUDENT CONFIRMED...
# ['202210049725BA', 'Okoye Mmesoma Charles', 'M', 'ANAMBRA', 166, 'Medicine & Surgery', nan, 'Not Admitted', 'ANAMBRA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'IDEMILI-NORTH', '09132691744']
# ==================================================
#               END MINING     No.   1134
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210055340FF : index : 1135
# ===================================================
# fetching content
# Surname :  Enyede
# Fist Name :  Dominic
# Other Name :
# Telephone :  08104321304
# Registion Number :  202210055340FF
#                      STUDENT CONFIRMED...
# ['202210055340FF', 'Enyede Dominic', 'M', 'BENUE', 166, 'Biology', nan, 'Not Admitted', 'BENUE', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ADO', '08104321304']
# ==================================================
#               END MINING     No.   1135
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210061198CF : index : 1136
# ===================================================
# fetching content
# Surname :  Eruonye
# Fist Name :  Joshua
# Other Name :
# Telephone :  07033745492
# Registion Number :  202210061198CF
#                      STUDENT CONFIRMED...
# ['202210061198CF', 'Eruonye Joshua', 'M', 'ABIA', 166, 'Computer Science', nan, 'Not Admitted', 'ABIA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'UMUAHIA-NORTH', '07033745492']
# ==================================================
#               END MINING     No.   1136
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210068903HA : index : 1137
# ===================================================
# fetching content
# Surname :  Jatau
# Fist Name :  Gerald
# Other Name :  Chigozie
# Telephone :  08160276055
# Registion Number :  202210068903HA
#                      STUDENT CONFIRMED...
# ['202210068903HA', 'Jatau Chigozie Gerald', 'M', 'KADUNA', 166, 'Computer Science', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'ZANGO-KATAF', '08160276055']
# ==================================================
#               END MINING     No.   1137
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210069450JA : index : 1138
# ===================================================
# fetching content
# Surname :  Audu
# Fist Name :  Awaeyi
# Other Name :  Juliet
# Telephone :  07089326673
# Registion Number :  202210069450JA
#                      STUDENT CONFIRMED...
# ['202210069450JA', 'Audu Juliet Awaeyi', 'F', 'NASARAWA', 166, 'Drama/Dramatic/Performing Arts', nan, 'Not Admitted', 'NASARAWA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'LAFIA', '07089326673']
# ==================================================
#               END MINING     No.   1138
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210070695EA : index : 1139
# ===================================================
# fetching content
# Surname :  Omofaiye
# Fist Name :  Zainab
# Other Name :
# Telephone :  08114045000
# Registion Number :  202210070695EA
#                      STUDENT CONFIRMED...
# ['202210070695EA', 'Omofaiye Zainab', 'F', 'KOGI', 166, 'Public Administration', nan, 'Not Admitted', 'KOGI', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'IJUMU', '08114045000']
# ==================================================
#               END MINING     No.   1139
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210070768FF : index : 1140
# ===================================================
# fetching content
# Surname :  Aliyu
# Fist Name :  Aishat
# Other Name :
# Telephone :  08056082237
# Registion Number :  202210070768FF
#                      STUDENT CONFIRMED...
# ['202210070768FF', 'Aliyu Aishat', 'F', 'KWARA', 166, 'Medicine & Surgery', nan, 'Not Admitted', 'KWARA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'OFFA', '08056082237']
# ==================================================
#               END MINING     No.   1140
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210070874JF : index : 1141
# ===================================================
# fetching content
# Surname :  Suleiman
# Fist Name :  Amirah
# Other Name :  Hauwa
# Telephone :  09154942439
# Registion Number :  202210070874JF
#                      STUDENT CONFIRMED...
# ['202210070874JF', 'Suleiman Hauwa Amirah', 'F', 'KWARA', 166, 'Business Administration', nan, 'Not Admitted', 'KWARA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'EDU', '09154942439']
# ==================================================
#               END MINING     No.   1141
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210074030IF : index : 1142
# ===================================================
# fetching content
# Surname :  Ikonallah
# Fist Name :  Happiness
# Other Name :
# Telephone :  07045207258
# Registion Number :  202210074030IF
#                      STUDENT CONFIRMED...
# ['202210074030IF', 'Ikonallah Happiness', 'F', 'ADAMAWA', 166, 'Economics', nan, 'Not Admitted', 'ADAMAWA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'GOMBI', '07045207258']
# ==================================================
#               END MINING     No.   1142
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210074454FF : index : 1143
# ===================================================
# fetching content
# Surname :  Hiram
# Fist Name :  Pwausoko
# Other Name :
# Telephone :  07047396022
# Registion Number :  202210074454FF
#                      STUDENT CONFIRMED...
# ['202210074454FF', 'Hiram Pwausoko', 'M', 'ADAMAWA', 166, 'Agriculture', nan, 'Not Admitted', 'ADAMAWA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'NUMAN', '07047396022']
# ==================================================
#               END MINING     No.   1143
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210091694CA : index : 1144
# ===================================================
# fetching content
# Surname :  Dambo
# Fist Name :  Albert
# Other Name :
# Telephone :  09044169374
# Registion Number :  202210091694CA
#                      STUDENT CONFIRMED...
# ['202210091694CA', 'Dambo Albert', 'M', 'KADUNA', 166, 'Mechanical Engineering', nan, 'Not Admitted', 'KADUNA', 'UNIVERSITY OF ABUJA, ABUJA, FCT', 'KAGARKO', '09044169374']
# ==================================================
#               END MINING     No.   1144
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210094271FF : index : 1145
# ===================================================
# fetching content
# ==================================================
#               END MINING     No.   1145
# ==================================================
#
# ===================================================
#    START MINING   FOR :  202210099831JA : index : 1146
# ===================================================
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [40], in <cell line: 43>()
#      54 print(f'   START MINING   FOR :  {reg} : index : {index}  ')
#      55 print('===================================================')
# ---> 57 data , lenght = fetch_info(reg)
#      58 if lenght != 0 :
#      59
#      60     # printing data for confirmation
#      61     try:
#
# Input In [40], in fetch_info(reg_number)
#      17 def fetch_info(reg_number):
#      18     driver.get('https://efacility.jamb.gov.ng/PrintExaminationSlip')
# ---> 19     reg = driver.find_element('id' , "txtRegNumber")
#      20     reg.send_keys(reg_number)
#      22     # submitting form
#      23     # reg.submit()
#
# File c:\users\binary\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File c:\users\binary\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File c:\users\binary\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="txtRegNumber"]"}
#   (Session info: chrome=105.0.5195.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0056DF13+2219795]
# 	Ordinal0 [0x00502841+1779777]
# 	Ordinal0 [0x0041423D+803389]
# 	Ordinal0 [0x00443025+995365]
# 	Ordinal0 [0x004431EB+995819]
# 	Ordinal0 [0x00470F52+1183570]
# 	Ordinal0 [0x0045E844+1108036]
# 	Ordinal0 [0x0046F192+1175954]
# 	Ordinal0 [0x0045E616+1107478]
# 	Ordinal0 [0x00437F89+950153]
# 	Ordinal0 [0x00438F56+954198]
# 	GetHandleVerifier [0x00862CB2+3040210]
# 	GetHandleVerifier [0x00852BB4+2974420]
# 	GetHandleVerifier [0x00606A0A+565546]
# 	GetHandleVerifier [0x00605680+560544]
# 	Ordinal0 [0x00509A5C+1808988]
# 	Ordinal0 [0x0050E3A8+1827752]
# 	Ordinal0 [0x0050E495+1827989]
# 	Ordinal0 [0x005180A4+1867940]
# 	BaseThreadInitThunk [0x76648484+36]
# 	RtlValidSecurityDescriptor [0x77A42EC0+448]
# 	RtlValidSecurityDescriptor [0x77A42E90+400]

# %%
#     =====================================================================================   #
#                                       THIRD SECTION CODE  FOR REMINING...                                  #
#     =====================================================================================   #
#    START MINING   FOR :  202210099831JA : index : 1146
