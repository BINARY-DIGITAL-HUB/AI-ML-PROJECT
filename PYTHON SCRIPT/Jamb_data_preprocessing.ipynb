# %%
# import the csv from the source folder 
import pandas as pd 

data = pd.read_csv('MASTER_DETAIL/master_record.csv')
data.tail()
# Out:
#         Unnamed: 0          RG_NUM        RG_CANDNAME RG_SEX STATE_NAME  \
# 131481        1068  202210340434GA        Said Faisal      M     KADUNA
# 131482        1069  202210147356GA    Musa Abduljalal      M     KADUNA
# 131483        1070  202210215477DA   Musa Bint Halima      F     KADUNA
# 131484        1071  202210943753JF  Umar Musa Ibrahim      M     KADUNA
# 131485        1072  202210163166FA    Yakubu Emmanuel      M     KADUNA
#
#         RG_AGGREGATE                  CO_NAME  PUTMESCORE AdmissionStatus  \
# 131481           121       Islamic/Sharia Law         NaN    Not Admitted
# 131482           114         Computer Science         NaN    Not Admitted
# 131483           113  Nursing/Nursing Science         NaN    Not Admitted
# 131484           112        Political Science         NaN    Not Admitted
# 131485           110    Biological Science(S)         NaN    Not Admitted
#
#        State_Name1                                      Instname  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'RG_NUM', 'RG_CANDNAME', 'RG_SEX', 'STATE_NAME',
#        'RG_AGGREGATE', 'CO_NAME', 'PUTMESCORE', 'AdmissionStatus',
#        'State_Name1', 'Instname', 'LGA_Name', 'Contact'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131486 entries, 0 to 131485
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       131486 non-null  int64
#  1   RG_NUM           131486 non-null  object
#  2   RG_CANDNAME      131486 non-null  object
#  3   RG_SEX           131486 non-null  object
#  4   STATE_NAME       131486 non-null  object
#  5   RG_AGGREGATE     131486 non-null  int64
#  6   CO_NAME          131486 non-null  object
#  7   PUTMESCORE       0 non-null       float64
#  8   AdmissionStatus  131486 non-null  object
#  9   State_Name1      131486 non-null  object
#  10  Instname         131486 non-null  object
#  11  LGA_Name         131486 non-null  object
#  12  Contact          131486 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 13.0+ MB

# %%
data.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
data.head()
# Out:
#            RG_NUM                   RG_CANDNAME RG_SEX STATE_NAME  \
# 0  202210036624GA              Ekele Titi Mercy      F      BENUE
# 1  202210089090CF           Ayodele Victor Tayo      M       ONDO
# 2  202210099413JA  Alade Marvellous Oluwadunsin      M       ONDO
# 3  202210110738IF          Isaiah Praise Thomas      M      DELTA
# 4  202210142204HF       Jamiu Olasunkanmi Afeez      M        OYO
#
#    RG_AGGREGATE                       CO_NAME  PUTMESCORE AdmissionStatus  \
# 0           170  Education & English Language         NaN    Not Admitted
# 1           170            Mass Communication         NaN    Not Admitted
# 2           170              Computer Science         NaN    Not Admitted
# 3           170                     Chemistry         NaN    Not Admitted
# 4           170               Performing Arts         NaN    Not Admitted
#
#   State_Name1                                           Instname     LGA_Name  \
# ...

# %%
sort_data = data.sort_values(by=data.columns[3] , axis=0, ignore_index=False)

# %%
sort_data[sort_data['STATE_NAME'] == 'GHANA']
# Out:
#                RG_NUM            RG_CANDNAME RG_SEX STATE_NAME  RG_AGGREGATE  \
# 65419  202211284032FF  Baidoo Abotar Victory      F      GHANA           170
#
#                 CO_NAME  PUTMESCORE AdmissionStatus State_Name1  \
# 65419  MILITARY SCIENCE         NaN    Not Admitted       GHANA
#
#                                              Instname LGA_Name     Contact
# 65419  NIGERIAN DEFENCE ACADEMY, KADUNA, KADUNA STATE  FOREIGN  9054051595

# %%
sort_data.head()
# Out:
#                 RG_NUM                     RG_CANDNAME RG_SEX STATE_NAME  \
# 3313    202211463753FF         Onwukwe Wisdom Williams      M       ABIA
# 106233  202211086823JF            Kalu Favour Amarachi      F       ABIA
# 42139   202211703809AF              Michael Obi Juliet      F       ABIA
# 106224  202210467605EA  Maduako Chinaecherem Happiness      F       ABIA
# 106215  202211755530IF               Azubugwu Amarachi      F       ABIA
#
#         RG_AGGREGATE                  CO_NAME  PUTMESCORE AdmissionStatus  \
# 3313             155    Aerospace Engineering         NaN    Not Admitted
# 106233           148       Medicine & Surgery         NaN    Not Admitted
# 42139            159  Business Administration         NaN    Not Admitted
# 106224           148  Nursing/Nursing Science         NaN    Not Admitted
# 106215           149  Nursing/Nursing Science         NaN    Not Admitted
#
#        State_Name1                                           Instname  \
# ...

# %%
# exporting data to csv file....
sort_data.to_csv('sort_master_record.csv', index=False)

# %%
sort_data.columns
# Out:
# Index(['RG_NUM', 'RG_CANDNAME', 'RG_SEX', 'STATE_NAME', 'RG_AGGREGATE',
#        'CO_NAME', 'PUTMESCORE', 'AdmissionStatus', 'State_Name1', 'Instname',
#        'LGA_Name', 'Contact'],
#       dtype='object')

# %%
states = list(sort_data['STATE_NAME'].unique())
states

for state in states:
    sort_data[sort_data['STATE_NAME'] == state]
